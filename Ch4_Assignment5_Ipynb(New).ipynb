# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeE757/CSC221_MEMAN002/blob/main/Ch4_Assignment5_Ipynb(New).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from traitlets.traitlets import Integer
magicians=['Alice','David','Carolina']
for magician in magicians:
  print(magician)

magicians=['Alice','David','Carolina']
for magician in magicians:
    print(f"{magician.title()}, that was a great trick!")

magicians=['Alice','David','Carolina']
for magician in magician:
    print(f"{magician.title()},that was a great trick!")
    print(f"I can't wait to see your next trick,{magician.title()}.\n")





magicians = ['Alice','david','Carolina']
for magicians in magicians:
    print(f"{magicians.title()},that was a great trick!")
    print(f"I can't wait to see your next trick,{magicians.title()}.\n")
    print("Thank you, everyone. That was a great magic show!")

for value in range(1,5):
    print(value)

for value in range(1,6):
    print(value)

numbers = list(range(1,6))
print(numbers)

even_numbers = list(range(2,11,2))
print(even_numbers)


for num in range(1,21):
  print(num)

for number in range(1,100001):
  print(number)


numbers = list(range(1000001))
print("Minimum number:", min(numbers))
print("Maximum number:", max(numbers))
print("Sum of numbers:",sum(numbers))


odd_numbers = list(range(1,21,2))
print(number)

multiples_of_3=[]
for number in range(3,31,3):
    multiples_of_3.append(number)
for number in multiples_of_3:
    print(number)

cubes = []
for number in range(1,11):
  cube = number**3
  cubes.append(cube)
for cube in cubes:
  print(cube)

cubes = [number**3 for number in range(1,11)]
for cube in cubes:
    print(cube)

players = ['Charles', 'martina', 'Michael','Florence', 'Eli']
print(players[0:3])

players = ['Charles','Martina','Michael','Florence','Eli']
print(players[1:4])

players =['Charles','Martina','Michael','Florence','Eli']
print(players[:4])

players = ['Charles', 'Martina', 'Michael', 'Florence', 'Eli']
print(players[2:])


players = ['Charles','Martina','Florence','Eli']
print(players[-3:])

print("Here are the first three players on my team:")
for players in players[:3]:
      print(players.title())

my_food = ['Pizza','Falafel','Carrot cake']
friend_food = my_food[:]
print("My favorite food are:")
print(my_food)
print("\nMy friend's favorite food are:")
print(friend_food)


program_list=['Pizza','Falafel','Carrot cake','Water']
print("The first three items in the list are:")
print(program_list[:3])

program_list =['Pizza','Falafel','Carrot cake','Water']
print("Three items from the middle of the list are:")
middle_index = len(program_list)//2
print(program_list[middle_index-1:middle_index+2])


my_list =['Pizza','Falafel','Carrot cake','Water']
message = "The last three items in the list are:"
last_three_items = my_list[-3:]
print(message)

pizza_list=["Margherita","Pepperoni","Hawaiian"]
new_pizza = "Supreme"
pizza_list.append(new_pizza)
print(pizza_list)

friend_pizza=["Cheese","Vegetarian", "BBQ chicken"]
new_pizza="Mushrooom"
friend_pizza.append(new_pizza)
print(friend_pizza)

my_favorite_pizza = []
friend_food_pizza = []
my_favorite_pizza.append("Marghrita")
my_favorite_pizza.append("Pepperoni")
my_favorite_pizza.append("BBQ Chicken")
friend_food_pizza.append("Superme")
friend_food_pizza.append("Hawaiian")
friend_food_pizza.append("Mushroom")

my_favorite_foods =["Pizza","Burger","Sushi"]
friend_food_foods =["Pasta","Steak","Ice Cream"]
for food in my_favorite_foods:
  print(food)

dimension = (200,50)
print(dimension[0])
print(dimension[1])

dimensions = (200, 50)
for dimension in dimensions:
  print(dimension)

dimension = (200,50)
print("Original dimensions:")
for dimension in dimensions:
    print(dimension)

dimensions = (400 , 100)
print("\nModified dimemsions:")
for dimension in dimensions:
  print(dimension)

foods = ('Pizza', 'Burger','Salad','Pasta','Fruit')
for food in foods:
    print(food)

foods = ('Pizza','Burger','Salad','Pasta','Fruit')
foods_list =(foods)
foods_list[1] ='Sushi'
foods_list[3] ='Chicken'
foods = tuple(foods_list)
for food in foods:
  print(food)

def factorial(n):
    if n < 0:
      raise ValueError("Input must be a positve integer.")
    elif n == 0:
         return 1
    else:
      result = [1]
      for i in range(2,n+1):
          carry = 0
          for j in range(len(result)):
            temp = result[j] * i + carry
            result[j] = temp % 10
            carry = temp // 10
          while carry:
            result.append(carry % 10)
            carry //= 10
          result.reverse()
          return int(".join(map(str, result")


def factorial(n):
  if n < 0:
    raise ValueError("Input must be a positive integer.")
  elif n == 0:
    return 1
  else:
    number = [i for i in range(1,n+1)]
    result = 1
    for num in numbers:
     result*=num
    return result

print(factorial(5))
print(factorial(10))
print(factorial(20))
print(factorial(50))
