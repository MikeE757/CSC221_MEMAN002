# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeE757/CSC221_MEMAN002/blob/main/distilled_chapter4assignment20_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import XATTR_SIZE_MAX
from datetime import date
from binascii import b2a_base64
from typing_extensions import is_typeddict
a = 34 #Create an integer
n = a.numerator #Get the numerator (an attribute)
b = [1,2,3] #Create a list
b.append(7) #Add a new element using the append method
c = a + 10 # c = 34 + 10
d = b + [4 ,5] #d = [1,2,3,4,7,4,5]
# Compare two object
def compare(a , b):
    if a is b:
       print('same object')
    if a == b:
       print('same value')
    if type(a) is type (b):
       print('same type')
a = [1,2,3]
b = [1,2,3]
compare(a,b)
items = list()
if isinstance(items , list):
  items.append(items)
def removeal(items: list , item) -> list:
    return [i for i in items if i !=item]
class mylist(list):
      def removeal(self , val):
          return [i for i in self if i != val]
# Example
items = mylist([5,8,2,7,2,13,9])
x = items.removeal(2)
print(x)
if isinstance(items , (list , tuple)):
   maxval = max(items)
a = 37
b = a
c = []
c.append(b)
del a #Decrease reference count of 37
b = 42 #Decrease reference count of 37
c[0] = 2.0 #Derease reference count of 37
a = 37
import sys
7
a = {}
b = {}
a['b'] = b
b['a'] = a
del a
del b
def some_calculation():
    #Use data for some of a calculation
    # Release the data
    del data
    # Calculation continues
    a = [1,2,3,4,]
    b = a
    b is a
    a = [1,2,[3,4]]
    b = list(a)
    b is a
    False
    b.append(100)
    b
    [1,2 , [3,4] , 100]
    [1,2,3[3,4]]
    [1,2,[-100,4] , 100]
    [1,2,[-100,4]]
    import copy
    a = [1,2,[3,4]]
    b = copy.deepcopy(a)
    b[2][0] = -100
    b
    [1,2,[3,4]]
    a
    [1,2,[3,4]]
    from datetime import data
    d = data(2012 , 12 , 21)
    print(d)
    2012-12-21
    str(d)
    '2012-12-21'
    from datetime import date
    d = date(2012 , 12 , 21)
    print(d)
    2012-12-21
    str(d)
    2012-12-21
    d = date(2012 , 12 , 21)
    repr(d)
    'datetime.date(2012 , 12 , 21)'
    print(f'The date is: {d!r}')
    items = {'number':42}
    items['func'] = abs
    import math
    items['mod'] = math
    items['error'] = ValueError
    nums = [1,2,3,4]
    items['append'] = nums.append
    items['func'](-45)
    45
    items['mods'].sqrt(4)
    2.0
    x = int('a lot')
    print("Couldn't convert")
    items['append'](100)
    nums
    [1,2,3,4,100]
    line = 'ACME , 100 , 490.10'
    column_types = [str , int , float]
    parts = line.split(',')
    row = [ty(val) for ty , val in zip(column_types , parts)]
    row
    ['ACME' , 100 , 490.1]
    del a
    b = 42
    c[0] = 2.0
    a = 37
    import sys
    sys.getrefcount(a)
    a = {}
    b = {}
    a['b'] = b
    b['a'] = a
    del a # a contains reference to b
    del b # b contains reference to a
    a = [1,2,3,4,]
    b = a
    b is a
    True
    b[2] = -100
    a
    [1,2,-100,4]
    a = [1,2,[3,4]]
    b = list(a) #Create a shallow copy of a
    False
    b.append(100)# Append element to b
    b
    [1,2,[3,4],100]
    a #Notice that a is unchanged
    [1,2,[3,4]]
    b[2][0] = -100# Modify an element inside b
    b
    [1,2,[-100,4,100]]
    a # Notice the change inside a
    [1,2,[-100,4]]
    import copy
    a = [1,2,[3,4]]
    b = copy.deepcopy(a)
    b[2][0] = -100
    b
    [1,2,[-100,4]]
    a# Notice that a is unchanged
    [1,2,[3,4]]
    from datetime import date
    d = date(2012, 12 , 21)
    print(d)
    2012-12-21
    str(d)
    '2012-12-21'
    d = date(2012 , 12 , 21)
    repr(d)
    'datetime.data'(2012 , 12 , 21)
import numpy as np
prices = np.array([1.25 , 2.10 , 3.05])
units = np.array([50 , 20 , 25])
compute_cost=('prices' , 'quantities')
array=([62.5 , 42. , 76.25])
compute_cost=('a lot' , 10)
a = [2,3,4,5]
s = repr(a)
b = eval(s)
a = repr(f)
a = 42
b = 3.7
a.__add__(b)
b.__radd__(a)
45.7
a = [1 , 2 , 3]
b = a
a is b
c = [1 , 2 ,3]
a is c
False
a = 42
b = 52.3
a.__lt__(b)
b.__gt__(a)
True
f'{x:spec}'
format(x , 'spec')
'x is {0:spec}'.format(x)
a = [1,2,3,4,5,6]
len(a)
x = a[2]
a[1] = 7
del a[2]
5 in a
a = [1,2,3,4,5,6]
x = a[1:5]
a[1:3] = [10,11,12]
del a[1:4]
_iter = s._iter__()
while True:
    try:
       x = _iter.__next__()
    except StopIteration:
          break
for x in reversed([1,2,3]):
    print(x)
class FRange:
      def __init__(self , start , stop , step):
          self.start = start
          self.stop = stop
          self.step = step
      def __iter__(self):
          x = self.start
          while x < self.stop:
                yield x
                x +=self.step
      def __iter__(self):
          x = self.start
          while x < self.stop:
                yield x
                x+=self.step
                nums = FRange(0.0 , 1.0 , 0.1)
          for x in nums:
              print(x)
a = [2,3,4,5]
s = repr(a)
b = eval(s)
f = open('foo.txt')
a = repr(f)
a = 42
b = 3.7
a.__add__(b)
b.__radd__(a)
45.7
a[0:100:10]
b[1:10 , 3:20]
c[0:100:10 , 50:75:5]
a[... , 10:20]
__iter = s.__iter__()
while True:
    try:
      x = _iter.__next__()
    except StopIteration:
          break
