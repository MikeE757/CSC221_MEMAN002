# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeE757/CSC221_MEMAN002/blob/main/Ch5_Assignment6_Ipynb(New).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Default title text
cars = ['Audi','BMW','Subaru','Toyota']
for car in cars:
  if car == 'BMW':
      print(car.upper())
  else:
      print(car.title())

car = "BMW"
car == 'BMW'

car = 'Audi'
car == 'BMW'

car = 'Audi'
car == 'audi'

car = 'Audi'
car.lower() == 'audi'

car = 'Audi'
car.lower() == 'audi'

car = 'Audi'
car.lower() == 'audi'

requested_topping = 'Mushrooms'
if requested_topping != 'anchovies':
    print("Hold the anchovies!")

age = 18
age == 18

answer = 17
if answer != 42:
  print("That is not the correct answer. Plaese try again!")

age = 19
age < 21

age <=21
age > 21
age>=21

age_0 = 22
age_1 = 18
age_0 =21 and age_1 >= 21
age_1 = 22
age_0 >=21 and age_1 >=21

requested_toppings = ['mushrooms','onions','pineapple']
'mushrooms' in requested_toppings
'pepperoni' in requested_toppings

banned_users = ['andrew','Carolina','David']
user = 'Marie'
if user not in banned_users:
  print(f"{user.title()}, you can post a response if you wish")

game_active = True
can_edit = False

car = 'Subaru'
print("Is car == 'Subaru'? I predict True.")
print(car == 'Subaru')
print("\nIs car == 'Audi'? I predict False.")
print(car == 'Audi')

string1 = "Apple"
string2 = "Apple"
string3 = "Banana"
print(string1 == string2)#True
print(string2 == string3)#False

string1 = "APPLE"
string2 = "apple"
string3 = "BANANA"
print(string1.lower() == string2.lower())#True
print(string1.lower() == string3.lower())#False


x =5
y = 10
z = 5
#Equality
print(x == y)# False(5 is not equal to 10)
print(x == z)#True(5 is equal to 5)
# Inequailty
print(x!=y)#True( 5 is not equal to 10)
print(x!=z)#False(5 is equal to 5)
#Greater than
print(x > y)#False(5 is not greater than 10)
print(y > x)#True(10 is not less than 5)
#Less tthan
print(x < y)#True(5 is less than 10)
print(y < x )#False(10 is not less than 5)
#Greater than or equal to
print(x >=y)#False(5 is not greater than or equal to 10)
print(x>=z)#True(5 is equal to 5)
#Less than or equal to
print(x<=y)#True(5 is less than or equal to 10)
print(y<=x)#False(10 is not less than or equal to 5)


age = 19
if age >= 18:
  print("You are old enough to vote!")

age = 19
if age >= 18:
    print("You are old enough to vote!")
    print("Have you registerd to vote yet?")

age = 17
if age >=18:
    print("You are old enough to vote!")
    print("Have you registered to vote yet!")
else:
    print("Sorry, you are too young to vote.")
    print("Please register to vote as soon as you turn 18!")

age = 12
if age < 4:
   print("Your admisson cost is $0.")
elif age < 18:
    print("Your admission cost is $25.")
else:
    print("Your admission cost is $40.")

age = 12
if age < 4:
    price = 0
elif age < 18:
    price = 25
else:
    price = 40

age = 12
if age < 4:
    price =0
elif age < 18:
    price = 25
elif age < 65:
    price = 40
else:
    price = 20
print(f"Your admission cost is ${price}.")

car = 'Subaru'
print("Is car == 'Subaru'? I predict True.")
print(car == 'Subaru')
print("\nIs car == 'Audi'? I predict False.")
print(car == 'Audi')

car = 'Chevorlet'
print("Is Chevorlet == 'Chevorlet'? I predict True.")
print(car == 'Chevorlet')
print("\nIs car == 'Chevorlet'? I predict False.")
print( car == 'Chevorlet')

car = 'Dodge'
print("Is Dodge == 'Dodge'? I predict True.")
print(car == 'Dodge')
print("\nIs car == 'Dodge'? I perdict False.")
print( car == 'Dodge')

car = 'Plymouth'
print("Is Plymouth == 'Plymouth'? I predict True.")
print( car == 'Plymouth')
print("\nIs car == 'Plymouth'? I perdict False.")
print( car == 'Plymouth')

car = 'Pontiac'
print("Is Pontiac == 'Pontiac'? I perdict True.")
print(car == 'Pontiac')
print("\nIs car == 'Pontaic'? I perdict False.")
print(car == 'Pontiac')

car = 'Ford'
print("Is Ford == 'Ford'? I perdict True.")
print( car == 'Ford' )
print("\nIs car == 'Ford'? I perdict False.")
print(car == 'Ford' )

car = 'Lamborghini'
print("Is car == 'Lamborghini'? I perdict True.")
print(car == 'Lamborghini')
print("\nIs car == 'Ferrari'? I perdict False." )
print(car == 'Ferrari')


car = 'Aston Martin'
print("Is car == 'Aston Martin'? I perdict True.")
print(car == 'Aston Martin' )
print("\nIs car == 'Maserati'? I perdict False.")
print( car == 'Maserati')


car = 'Audi'
print("Is car == 'Audi'? I perdict True.")
print(car == 'Audi')
print("\nIs car == 'Saab'? I perdict False.")
print( car == 'Saab')


car = 'Saleen'
print("Is car == 'Saleen'? I perdict True.")
print(car == 'Saleen')
print("\nIs car == 'Pagani'? I perdict False")
print( car == 'Pagani')

car = 'McLaren'
print("Is car == 'McLaren'? I perdict True.")
print( car == 'McLaren')
print("\nIs car == 'Gemballa'? I perdict False.")
print( car == 'Gemballa')

Alien_color = 'green'
if Alien_color == 'green':
   print("The Alien was shot down! You earned 5 pioints!")
elif Alien_color == "Yellow":
  print("The Alien was shot down! You earned 10 points!")
elif Alien_color == 'red':
    print("The Alien was shot down! You earned 15 points!")
else:
  print("Invaid Alien color!")


Alien_color ='Green'
if Alien_color == 'Green':
  print("Congratulations! You shot down a Green Alien!")
elif Alien_color == 'Yellow':
  print("Congratulations! You shot down a Yellow Alien!")
elif Alien_color == 'Red':
  print("Congratulations! You shot down a Red Alien!")


Alien_color == 'Green'
if Alien_color == 'Green':
    print("Congratulations! You just earned 5 points for shooting the Alien!")
else:
  print("You missed the Alien. No points earned.")

if Alien_color == 'Green':
    print("Congratulations! You just earned 5 points for shooting the green Alien!")
else:
    print("Congratulations! You just earned 10 points for shooting the Alien!")

Alien_color = 'Red'
if Alien_color == 'Green':
    print("Congratulations! You just eanred 5 points for shooting the Green Alien!")
else:
    print("Congratulations! You just earned 10 points for shooting the Alien!")

Alien_color = 'Green'
if Alien_color == 'Green':
  print("Congratulations! You just earned 5 points for shooting the green Alien!")
elif Alien_color == "Yellow":
  print("Congratulations! You just earned 10 points for shooting the yellow Alien!")
elif Alien_color == 'Red':
    print("Congratulations! You just earned 15 points for shooting the Red Alien!")
else:
  print("You missed the Alien.No points earned.")


Alien_color = 'Yellow'
if Alien_color == 'Green':
    print("Congratulations! You just earned 5 points for shooting the Green Alien!")
elif Alien_color == 'Yellow':
  print("Congratulations! You just earned 10 points for shooting the Yellow Alien!")
elif Alien_color == 'Red':
  print("Congratulations! You just earned 15 points for shooting the Red Alien!")
else:
  print("You missed the Alien. No points earned.")

Alien_color = 'Red'
if Alien_color == "Green":
    print("Congratulations! You just earned 5 points for shooting the Green Alien!")
elif Alien_color == "Yellow":
    print("Congratulations! You earned 10 points for shooting the Yellow Alien!")
elif Alien_color == "Red":
    print("Congratulations! You just earned 15 points for shooting the Red Alien!")
else:
    print("You missed the Alien. No points earned.")


#Version 1 Green Alien
Alien_color = 'Green'
if Alien_color == 'Green':
   print("Congratulations! You just earned 5 points for shooting the Green Alien!")
elif Alien_color == 'Yellow':
      print("Congratulations! You just earned 10 points for shooting the Yellow Alien!")
elif Alien_color == 'Red':
      print("Congratulations! You just earned 15 points for shooting the Red Alien!")
else:
  print("You missed the Alien. No points earned.")


#Version 2 Yellow Alien
Alien_color = 'Yellow'
if Alien_color == 'Green':
  print("Congratulations! You just earned 5 points for shooting the Green Alien!")
elif Alien_color == "Yellow":
  print("Congratulations! You just earned 10 points for shooting the Yellow Alien!")
elif Alien_color == 'Red':
    print("Congratulations You just eanred 15 points for shooting the Red Alien!")
else:
  print("You missed the Alien. No points earned.")


#Version 3 Red Alien

Alien_color = 'Red'
if Alien_color == 'Green':
  print("Congratulations! You just earned 5 points for shooting the Green Alien!")
elif Alien_color == 'Yellow':
    print("Congraulations! You just earned 10 points for shooting the Yellow Alien!")
elif Alien_color == 'Red':
    print("Congratulations! You just earned 15 points for shooting the Red Alien!")
else:
  print("You missed the Alien. No points earned.")


age = 1
if age < 2:
    print("The person is a baby.")
elif age < 4:
    print("The person is a toddler.")
elif age < 20:
  print("The person is a teenager.")
elif age < 65:
  print("The person is a adult.")
else:
  print("The person is a senor.")

age = 3
if age < 2:
    print("The person is a baby.")
elif age >= 2 and age < 4:
    print("The perosn is a toddler.")
elif age < 13:
    print("The person is a child.")
elif  age < 20:
    print("The person is a teenager.")
elif age < 65:
    print("The person is an adult.")
else:
    print("The person is a senor.")

age = 15
if age is 2:
  print("The person is a baby.")
elif age >=2 and age < 4:
    print("The person is a toddler.")
elif age >=13 and age <20:
    print("The person is adult.")
elif age >= 65:
    print("The person is as senior.")
else:
    print("The person is child.")

age = 4
if age >=13 and age < 20:
    print("The person is a teenager.")
elif age >=4 and age < 13:
    print("The person is a kid.")
elif age >=20 and age <65:
    print("The person is a senior.")
else:
  print("The person is a child.")

age = 25
if age >= 13 and age<20:
  print("The person is teenager.")
elif age >=4 and age < 13:
    print("The person is a kid.")
elif age >= 20 and age < 65:
    print("The person is a adult.")
elif age >= 65:
    print("The person is a senior.")
else:
    print("The person is a child.")

age = 70
if age >=13 and age < 20:
  print("The person is a teensger.")
elif age >=4 and age < 13:
  print("The person is a kid.")
elif age >= 20 and age < 65:
  print("The person is an adult.")
elif age >= 65:
    print("The person is an elder.")
else:
  print("The person is a child.")


favorite_fruits = ['Apple','Banana', 'Mango']
if 'Apple' in favorite_fruits:
    print("Apple is one of my favorite Fruits.")
if 'Banana' in favorite_fruits:
    print("Banana is one of my favorite Fruits.")
if 'Mango' in favorite_fruits:
    print("Mango is one of my favorite Fruits.")
if 'Orange' in favorite_fruits:
    print("Orange is one of my favorite Fruits.")
if 'Strawberry' is favorite_fruits:
    print("Strawberry is one of my favorite fruits.")

favorite_fruits = ['Apple','Banana', 'Mango']
if 'Apple' in favorite_fruits:
    print("You really like Apples.")
if 'Banana' in favorite_fruits:
    print("You really like Bananas.")
if 'Mango' in favorite_fruits:
    print("You really like Mangos.")
if 'Orange' in favorite_fruits:
    print("You really like Strawberries.")

requested_toppings = ['Mushrooms','Green peppers', 'extra cheese']
for requested_topping in requested_toppings:
 if requested_topping == 'Green Peppers':
    print("Sorry, we out of Green pepper right now.")
else:
    print(f"Adding {requested_toppings}.")
print("\nFinished making your own pizza!")

username = ['John','Sarah','Admin','Michael','Amy']
for username in username:
    if username == 'Admin':
       print("Hello Admin, would you like to see a staus report?")
else:
    print(f"Hello{username}, welcome back!")

username = ['John','Sarah','Admin','Michael','Amy']
for username in username:
   if username == 'Admin':
    print("Hello Admin, would you like to see a staus report?")
else:
    print(f"Hello{username},thank you for logging in again.")

username = []
if username in username:
  for username in username:
    if username == 'Admin':
      print("Hello Admin, would you like to see a status report?")
  else:
    print(f"Hello {username},thank you for logging in again.")
else:
  print("We need to find some user!")

username = []
if len(username) > 0:
    for username in username:
      if username == 'Admin':
        print("Hello Admin, would you like to see a status report?")
      else:
              print("We need to find some users!")

current_users =['John','Jessica','Alex','Daniel','Paul']
new_users = ['John','Jessica','Alex','Daniel','Paul']
for new_user in new_users:
  if new_user.lower() in [user.lower() for user in current_users]:

        print(f"Sorry, the user{'new_user'} is already taken.Please choose a different username")
  else:
        print(f"The username'{new_user}' is available.")

current_users = ['John','Emma','Alex','Sarah','Hill']
new_user = ['John','Paul','Jill','Jessica','Alex','Daniel']
for new_user in new_users:
  if new_user.lower() in [user.lower() for user in current_users]:
    print(f"Sorry, the username'{new_user}' is already taken. Please choose a different username.")
  else:
      print(f"The username'{new_user}' is available.")
