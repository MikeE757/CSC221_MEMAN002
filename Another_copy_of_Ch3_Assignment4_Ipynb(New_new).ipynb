# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeE757/CSC221_MEMAN002/blob/main/Another_copy_of_Ch3_Assignment4_Ipynb(New_new).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ast import Index
bicycles = ['trek' , 'cannondale', 'redline', 'specialized']
print(bicycles)

biycles = ['trek','cannonable','redline','specialized']
print(bicycles[0])

bicycles = ['trek','cannondale','redline','specialized']
print(bicycles[0].title())

bicycles=['trek','cannondale','redline','specialized']
print(bicycles[1])
print(bicycles[3])

bicycles=['trek','cannondale','redline','specialized']
print(bicycles[-1])

bicycles=['trek','cannondale','redline','specialized']
message=f"My first bicycle was a {bicycles[0].title()}"
print(message)

motorcycles = ['Honda','Yamaha','Suzuki']
print(motorcycles)

motorcycles[0] ='Ducati'
print(motorcycles)

motorcycles = ['Honda','Yamaha','Suzuki']
print(motorcycles)

motorcycles.append('Ducati')
print(motorcycles)

motorcycles = []
motorcycles.append('Honda')
motorcycles.append('Yamaha')
motorcycles.append('Suzuki')
print(motorcycles)


name=["Alice","Bob","Charile","David"]
for name in name:
  print(name)


name = ["Alice","Bob","Charile","David"]
for name in name:
  message =f"Hello,{name}!How are you today?"
  print(message)

transportation_modes=["motocrycle","car","bicycle","train","helicopter"]
print(f"I would like to own a car,bicycle,train,helicopter.")


motorcycles=['Honda','Yamacha','Suzuki']
last_owed = motorcycles.pop()
print(f"The last motorcycle I owed was a (last_owed.title().")

motorcycles=['Honda','Yamaha','Suzuki','Ducati']
print(motorcycles)

motorcycles.remove('Ducati')
print(motorcycles)


guest_list=['Albert Einstein', 'Leonardo da Vinci', 'Marie Curie']
print(f"Dear Albert, Leonardo, Marie, you are cordially invited to dinner. Please join us!")

cars =['bmw','audi','toyota','subaru']
cars.sort()
print(cars)

cars=['bmw','audi','toyata','subaru']
cars.sort(reverse=True)
print(cars)

cars=['bmw','audi','toyota','subaru']
print(cars)
cars.reverse()
print(cars)

Guest = ["Alice" , "Bob" , "Charlie"]
#print the orginal Guest list:
print("Orginal Guest list:")
for guest in guest_list:
  print(guest)
guest_list[1] = "David"
print("\nUfortunately, Bob can't make it to the dinner.")

guest = ["Alice" , "Bob" , "Charlie"]
print("Orginal Guest list")
for guest in guest:
  print(guest)
print("\nUpdated Guest List:")
for guest in guest:
  print(guest)
cannot_attend = "Bob"
print(f"\nUnfortunately,{cannot_attend} can't make it to the dinner.")
new_person = 'Eve'
guest[guest.index,{cannot_attend}] = "Eve"
print("\nFinal Guest List:")
for guest in guest:
  print(guest)

guest ["Alice" , "Bob" , "Charlie"]
print("Original Guest List:")
for guest in guest:
  print(guest)
guest[1] = "David"
print("\nUpdate guest List:")
for guest in guest:
  print(guest)
cannot_attend = "Bob"
print(f"\nUfortunately,{cannot_attend} can't make it to the dinner.")
new_person
print("\nFinal Guest List:")
for guuest in guest:
  print(guest)
print("\nInvitation Message:")
for guest in guest:
  message = f"Dear{guest} , you are cordialy invited to dinner at my place. Please join us!"
  print(message)

guests = ["Alice" , "Bob" , 'Charlie']
print("Original Guest List:")
for guest in guest:
  print(guest)
  guest[1] = "David"
print("\nUpdate Guest List:")
for guest in guest:
  print(guest)
cannot_attend = "Bob"
print(f"\nUnfortunately,{cannot_attend} can't make it to the the dinner.")
new_person = "Eve"
guest[guest.index(cannot_attend)] = new_person
print("\nFinal Guest List:")
for guest in guest:
  print(guest)
guest.append("Frank")
guest.append("Grace")
guest.append("Hannah")
print("\nUpdated Guest List with Additional Guest:")
for guest in guest:
  print(guest)
print("\nGreat news! We found a bigger dinner table!")


guest = ["Alice" , "Bob" , "Charlie"]
print("Original Guest List:")
for guest in guest:
  print(guest)
cannot_attend = "Bob"
print(f"\nUnforunately , {cannot_attend} can't make it to the the dinner.")
new_person = "Eve"
guest[guest.index(cannot_attend)] = new_person
print("\nFinal Guest List:")
for guest in guest:
  print(guest)
guest.insert(1,"Frank")
guest.append('Grace')
guest.append("Hannah")
print("\nUpdated Guest List with additional Guest:")
for guest in guest:
  print(guest)
print("\nGreat news! We found a bigger dinner table!")

guest =["John" , "Mary" , "David"]
guest.append("Sarah")
print(guest)

guest = ["John" , "Mary" , "David"]
guest.append("Sarah")
guest.appebnd("Michael")
guest.append("Emily")
for guest in guest:
  print(f"Dear{guest}, you are cordially invited to dinner at my place. Please join us on Saturday at 7PM.")
print("Oops! It seems that the new dinner table won't arrive in time. I can only invite two people for dinner.")

guests =["John" , "Mary" , "David" , "Sarah" , "Michael" , "Emily" , "Daniel"]
while len(guest) > 2:
  removed_guest = guest.pop()
  print(f"Sorry,{removed_guest},I'm afriad I can't invite you to dinner.")
for guest in guest:
  print(f"Dear {guest}, you are still invited to dinner at my place. Please join us on Saturday at 7PM.")

cars = ["BMW" , "Audi" , "Toyota" , "Subaru"]
cars.sort()
print(cars)

cars = ['BMW' , 'Audi' , 'Toyota' , 'Subaru']
cars,sort(reserse = True)
print(cars)

cars = ['BMW' , 'Audi' , 'Toyota' , 'Subaru']
print(cars)
cars.reverse()
print(cars)

cars = ['BMW' , 'Audi' , 'Toyota' , 'Subaru']
len(cars)

places_to_vist =['Machu Picchu, Peru' , 'Santorini , Greece' , 'Serengeti National Park Tanzania','Kyoto , Japan' , 'Petra, Jordan']
print(sorted(places_to_vist))

places_to_vist = ['Machu Picchu, Peru' , 'Santorini, Greece' , 'Serengeti National Park , Tazania', 'Kyoto, Japan' ,'Petra, Jordan']
print(sorted(places_to_vist, reverse = True))

places_to_vist = ['Machu Picchu , Peru' , 'Santorini , Greece' , 'Serengeti National Park Tanzania' , 'Kyoto , Japan' , 'Petra, Jordan']
places_to_vist.reverse()
print(places_to_vist)

places_to_vist=['Machu Picchu , Peru' , 'Santorini , Greece' , 'Serengeti National Park , Tanzania' , 'Kyoto , Japan' , 'Perta , Jordan']
places_to_vist.sort()
print(places_to_vist)

guests = ['Alice' , 'Bob' , 'Charlie' , 'David']
for guest in guest:
  print(f"Dear{guest}, you are cordially invited to dinner.")
  num_guest = len(guest)
  print(f"\nNumber of people invited to dinner: {num_guest}")

  items = ['Mount Everest' , 'Nile River' , 'France' , 'New York City' ,'English']
  print(items[0])
  print(items[-1])
  items[2] = 'Italy'
  print(items)
  items.insert(3,'Berlin')
  print(items)
  removed_item = items.pop(1)
  print(removed_item)
  print(items)
  items.removed('New York City')
  print(items)
  items.sort()
  print(items)
  items.reverse()
  print(items)
  num_items = len(items)
  print(f"Number of items in the list:{num_items}")

  motorcycles = ['Honda' , 'Yamaha' , 'Suzuki']
  print(motorcycles[-1])

my_list = [1,2,3,]
print(my_list[3])

for num in range(60,86):
  if num % 7 == 0:
    print(num **3)


y = 7.4 * 40 + 51
y = 296 + 51
y = 347


y = 7.4 * 50 + 51
y = 370 + 51
y = 421


y = 7.4 * 120 + 51
y = 888 + 51
y = 939


y = 7.4 * -8 + 51
y = -59.2 + 51
y = -8.2


y = 7.4 * 6 + 51
y = 44.4 + 51
y = 95.4
# Out:
# ['trek', 'cannondale', 'redline', 'specialized']
# trek
# Trek
# cannondale
# specialized
# specialized
# My first bicycle was a Trek
# ['Honda', 'Yamaha', 'Suzuki']
# ['Ducati', 'Yamaha', 'Suzuki']
# ['Honda', 'Yamaha', 'Suzuki']
# ['Honda', 'Yamaha', 'Suzuki', 'Ducati']
# ['Honda', 'Yamaha', 'Suzuki']
# Alice
# Bob
# Charile
# David
# Hello,Alice!How are you today?
# Hello,Bob!How are you today?
# Hello,Charile!How are you today?
# Hello,David!How are you today?
# I would like to own a car,bicycle,train,helicopter.
# The last motorcycle I owed was a (last_owed.title().
# ['Honda', 'Yamaha', 'Suzuki', 'Ducati']
# ['Honda', 'Yamaha', 'Suzuki']
# Dear Albert, Leonardo, Marie, you are cordially invited to dinner. Please join us!
# ['audi', 'bmw', 'subaru', 'toyota']
# ['toyata', 'subaru', 'bmw', 'audi']
# ['bmw', 'audi', 'toyota', 'subaru']
# ['subaru', 'toyota', 'audi', 'bmw']
# Orginal Guest list:
# Albert Einstein
# Leonardo da Vinci
# Marie Curie
#
# ...
