# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeE757/CSC221_MEMAN002/blob/main/Chapter1_Assignment16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ctypes import addressof
print('Hello World')
6000 + 4523.50 + 134.35
print('Hello World')
x = 42
x : int = 42
2 + 3 * 4
# hello.py
print('Hello World')
42
4.2
'forty-two'
True
x = 42
x: int = 42
# interest.py
principal = 1000
rate = 0.05
numyear = 5
year = 1
a = 'Hello World'
b = 'Python is groovy'
c = 'Computer say no'
d = 'Computer still say no'
a = 'Hello World'
print(len(a))
b = a[4]
c=a[-1]
c = a[:5]
d = a[6:]
e = a[3:8]
f = a[-5:]
s = 'hello\nworld'
print(str(s))
x = '37'
y = '42'
z = x+y
z = int(x) + int(y)
s = 'The value of x is'  + str(x)
s = 'The vaule of x is'  +repr(x)
s = 'The value of x is'  +format(x , '4d')
s = 'Hello\nworld'
print(str(s))
print(repr(s))
x = 12.34567
format(x , '0.2f')
f'{x:0.2f}'
with open('data.txt') as file:
     for line in file:
         print(line , end='')
file = open('data.txt')
for line in file:
    print(line , end='')
file.close()
with open('data.txt') as file:
     data = file.read()
with open('data.txt') as file:
      while(chunk := file.read(10000)):
          print(chunk, end='')
with open('data.txt') as file:
     while True:
         chunk = file.read(10000)
         if not chunk:
          break
          print(chunk , end='')
with open('out.txt' , 'wt') as out:
    while year <= numberyears:
    principal = principal * (1 + rate)
    print(f'{year: >3d}{principal:0.2f}', file=out)
    year += 1
    out.write(f'{year:3d}{principal:0.2f}\n')
with open('data.txt' , encoding='latin-1') as file:
     data = file.read()
     name = input('Enter your name:')
     print('Hello , name')
     names = ['Dave' , 'Paula' , 'Thomas' , 'Lewis']
     a = names [2]
     names[2] = 'Tom'
     print(name[-1])
     for name in names:
      print(name)
     b = names[0:2] # b ->['Dave' , 'Paula]
     c = names[2:]  #c-> ['Aya' , 'Tom' , 'Lewis' , 'Alex']
     names[1] = 'Becky' #Replace 'Paula with 'Becky'
     name = [] # An empty list
     names = list()
     a[1] # Return 'Dave
     a[3][2] # 'Return 9
     a[3][3][1] # Return 101
     import sys
     if len(sys.argv) ! =2:
        raise SystemExit(f'Usage: {sys.argv[0]} filename')
        rows = []
        with open(sys.argv[1],'rt') as file:
             for line in file:
                 rows.append(line.split(','))
        # rows is a list of this form
        #[
        #['SYM' , '456.78' , '123']
        #]
        total = sum([int(row[1])* float(row[2]) for row in rows])
        values = []
        for row in rows:
          values.append(int(row[1]) * float(row[2]))
        total = sum(values)
        holding = ('GOOG' , 100 , 490.10)
        address = ('www.Python.org' , 80)
        a = ( ) #0-tuple(empty tuple)
        b = (item,)# 1-tuple(note the trailing comma)
        name , shares , price = holding
        host , port = address
        # File containing lines of the form '' name,shares,price"
        filename = 'portfolio.csv'
        portfolio = []
        with open(filename) as file:
             for line in file:
                 row = line.split(',')
                 name = row[0]
                 shares = int(row[1])
                 price = float(row[2])
                 holding = (name , shares , price)
                 portfolio.append(holding)
                 names1 =  {'IBM' , 'MSFT' , 'AA'}
                 names2 = set(['IBM' , 'MSFT' , 'HPE' , 'IBM' , 'CAT'])
                 names = {s[0] for s in portfolio}
                 r = set() #Initially empty set
                 a = t | s
                 b = t & s
                 c = t - s
                 d = s - T
                 e = t ^ s
                 t.add('DIS')
                 s.discard('SCOX')
                 s =  {'name' : 'GOOG' , 'share' : 100, 'price' : 490.10}
                 name = s['name']
                 cost = s['share'] * s['price']
                 s['share'] = 75
                 s['data'] = '2007 - 06 - 07'
                 prices = {'GOOG' : 490.1 , 'AAPL' : 123.5 , 'IBM' : 91.5 , 'MSFT' : 52.13}
                 p = prices['IBM']
                 if 'IBM' in prices:
                    p = prices['IBM']
                 else:
                     p = 0.0
                 p = prices.get('IBM' , 0.0) #prices['IBM'] if  it exists , else 0.0
                 del prices['GOOG']
                 prices = {}
                 prices[('IBM' , '2015-02-03')] = 91.23
                 prices['IBM' , '2015-02-04'] = 91.42 #Parents omitted
                 portfolio = [('ACME' , 50,92.34) , ('IBM' , 75 , 102.25) , ('PHP' , 40, 74.50) , ('IBM' , 50 , 124.75)]
                 total_shares = {s[0] : 0 for s in portfolio}
                 for name , shares, _ in portfolio:
                     total_shares[name] += shares
                # total_shares = ({'IBM' , : 125, 'ACME' , : 50 , 'PHP' : 40})
for n in [1,2,3,4,5,6,7,8,9]:
  print(f'2 to the {n} power is {2**n}')
for n in range(1,10):
    print(f'2 to the {n} power is {2**n}')
    a = range(5)
    b = range(1 ,8)
    c = range(0 , 14 , 3 )
    d = range(8, 1 , -1)
    message = 'Hello World'
    # Print out the individual characters in message
    for c in message
    name = ['Dave' , 'Mark' , 'Ann' , 'Phil']
    for name in names:
        print(name)
    prices = {'GOOG' : 490.10 , 'IBM' : 91.50 , 'AAPL' : 123.15}
    for key in prices:
        print(key , '=' , prices[key])
    #print all of the line in a file
    with open('foo.txt') as file:
         for line in file:
             print(line , end='')
    def remainder(a , b):
        q = a//b #// is truncating divison.
        r = a - q * b
        return r
    def remainder(a , b):
        q = a//b
        r = a - q * b
        return r
    def remainder(a: int , b: int) -> int:
        q = a//b
        r = a - q * b
        return r
    def divide(a,b):
        q = a//b #If a  and b are integers , q is interger
        r = a -q * b
        return(q , r)
        debug = True #Global Variable
    def read_data(filename):
        if debug:
           print('Reading' , filename)
    items = [37 , 42] # Create a list object
    items.append(73) # Call the append() method
    ['__add__' , '__close__' , '__contains__' , '__delattr__' , 'append' , 'count' , 'extend' , 'index' , 'insert' , 'pop' , 'remove' , 'reverse' , 'sort']
    class Stack:
         def __init__(self): #Initialze the stack
             self._items = []
        def push(self , item):
            self._items.append(item)
        def pop(self):
            return self._items.pop()
        def __repr__(self):
            return f'<{type(self).__name__} at Ox{id(self):x} , size={len(self)} >'
        def __len__(self):
            return len(self._items)
        def read_portfolio(filename):
            portfolio = []
            with open(filename) as file:
                 for line in file:
                  row = line.split(',')
                  try:
                     name = row[0]
                     shares = int(row[1])
                     price = float(row[2])
                     holding = (name , shares , price)
                     protfolio.append(holding)
                 except ValueError as err:
                 print('Bad row:' , row)
                 print('Reason:' , err)
           return portfolio
           import readport
        def portfolio_cost(filename):
            port = report.read_portfolio(filename)
            return sum(shares * price for _, shares , price in port)
import readport as rp
port = rp.read_portfolio('portfolio.dat')
from readport
['__builtins__' , '__cached__' , '__doc__'  , '__file__' , '__loader__' , '__name__' , '__package__' , '__spec__' , 'read_portfolio']
import csv
      def read_portfolio(filename):
      def main():
          portfolio = read_portfolio('portfolio.csv')
          for name , shares , price in portfolio:
              print(f'{name:>10s}{shares:10d}{price:10.2f}')
          if __main__ == 'main':
               name()
      def main(argv):
          if len(argv) == 1:
             filename = input('Enter filename')
          elif len(argv) == 2:
               filename = argv[1]
          else:
              raise SystemExit(f'Usage:{argv[0] [filename]}')
          portfolio = read_portfolio(filename)
          for name , shares , price in portfolio:
              print(f'{name:>10s}{shares:10}{price:10.2f}')
          if  __name__ == 'main':
              import sys
              main(sys,argv)
# Out:
#   File "<tokenize>", line 202
#     def push(self , item):
#     ^
# IndentationError: unindent does not match any outer indentation level
