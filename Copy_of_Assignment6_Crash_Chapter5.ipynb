# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeE757/CSC221_MEMAN002/blob/main/Copy_of_Assignment6_Crash_Chapter5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cars = ['audi' , 'bmw' , 'subaru' , 'toyota']
for car in cars:
    if car == 'bmw':
       print(car.upper())
    else:
        print(car.title())
car = 'bmw'
car == 'bmw'
car = 'audi'
car == 'bmw'
car = 'Audi'
car == 'audi'
car = 'Audi'
car == 'audi'
car = 'Audi'
car.lower() == 'audi'
car = 'Audi'
car.lower() == 'audi'
requested_topping = 'mushroom'
if requested_topping != 'anhovies':
   print("Holding the anhovies!")
age = 18
age == 18
answer = 17
if answer !=42:
  print("That is not the correct ")
  age = 19
  age < 21
age_0 = 22
age_1 = 18
age_0 >= 21 and age_1 >=21
age_1 = 22
age_0 >=21
age_1 = 22
age_0 >= 21 and age_1 >=21
age_0 = 22
age_1 = 18
age_0 >= 21 or age_1 >=21
age_0 = 18
age_0 >=21 or age_1 >=21
requested_toppings = ['mushroms' , 'onions' , 'pineapple']
'mushrooms' in requested_toppings
'pepperoni' in requested_toppings
banned_user = ['andrew' , 'carolina' , 'david']
user = 'marie'
if user not in banned_user:
   print(f"{user.title()}, you can post a resqonse if you wish.")
   game_active = True
   can_edit = False
   car = 'subaru'
   print("Is car == 'subaru' I pedict True.")
   print(car == 'subaru')
   print("\nIs car == 'audi'? I predict False.")
   print(car == 'audi')
   # Conditional test
   x = 5
   y = 10
   #Test 1: Check if x equal to 5
   print("Test 1: Is x equal to 5?")
   print(x==5)#True
   #Test 2: Check if y is not equal to 10
   print("Test 2: is y not equal to 10?")
   print(y!=10)#False
   #Test 3: Check if x less than y?
   print("Test 3: Is x less than y?")
   print(x,y)#True
   #Test 4: Check if y is greater than or equal to 10
   print("Test 4: Is y greater than or equal to 10?")
   print(y>=10)#True
   #Test 5: Check if x is greater than y
   print("Test 5: Is x greater than y?")
   print(x>y)#False
   #Conditional test
   a = 10
   b = 20
   c = 5
   d = 10
   e = 15
   #Test 1:Is a equal to 10?
   print("Test 1: Is a equal to 10?")
   print(a==10)#True
   #Test 2: Is b not eqaul to 10?
   print("Test2: Is b not equal to 10?")
   print(b!=10)#True
   #Test 3: Is c less than b?
   print("Test 3: Is c less than b?")
   print(c<b)#True
   #Test 4: Is d greater than or equal to 10?
   print("Test 4: Is d greater than or equal to 10?")
   print(d>=10)#True
   #Test 5: Is e less than b?
   print("Test5: Is e less than b?")
   print(e<b)#True
   #Test 6: Is not equal to 10?
   print("Test6: Is a not equal to 10?")
   print(a!=10)#False
   #Test 7: Is b equal to 20?
   print("Test 7: Is b equal to 20?")
   print(b == 20)#True
   #Test 8: Is c greater than or equal to 10?
   print("Test 8: Is c greater than or equal to 10?")
   print(c>=10)#False
   #Test 9: Is d less than a?
   print("Test 9: Is d less than a?")
   print(d<a)#False
   #Test 10: Is e equal to 20?
   print(e==20)# False
   #Conditional tests with strings
   string1 = "Hello"
   string2 = "World"
   string3 = "Hello"
   #Test 11: string1 equal to "Hello"?
   print("Test 11: Is string equal to 'hello?'")
   print(string1 == "hello")#True
   #Test 12: string2 not equal to "Hello"?
   print("Test 12: Is string2 not equal to 'hello'?")
   print(string2!= 'hello')#True
   #Test 13: Is string1 equal to string3?
   print("Test 13: Is string1 equal to string3?")
   print(string1 == string3)#False
   #Test 14: Is string2 equal to "World"?
   print("Test14: Is string2 equal to 'world?")
   print(string2 == "world")#True
   #Test 15: Is string1 not equal to string2?)
   print(string1 !=string2)#True
   age = 19
   if age >= 18:
     print("You are old enough to vote!")
age = 19
if age >=18:
   print("You are old enough to vote!")
   print("Have you registered to vote yet?")
age = 17
if age >= 18:
   print("You are old enough to vote!")
   print("Have you registered to vote yet?")
else:
    print("Sorry, you are too young to vote.")
    print("Please register to vote as soon as you turn 18!")
age = 12
if age < 4:
   print("Your admission cost is $0.00")
elif age < 18:
     print("Your admission cost is 25.00")
else:
    print("Your admission costn is 40.00")
age = 12
if age < 4:
   price = 0.00
elif age < 18:
     price = 25.00
else:
    price = 40.00
print(f"Your admission cost is ${price}.")
age = 12
if age < 4:
   price = 0.00
elif age < 18:
     price = 25.00
elif age < 65:
     price = 40.00
else:
     price = 20.00
print(f"Your admission cost is ${price}.")
age = 12
if age < 4:
   price = 0.00
elif age < 18:
     price = 25.00
elif age < 65:
     price = 40.00
elif age < 65:
     price = 20.00
print(f"Your admission cost is ${price}.")
requested_toppings = ['mushroom' , 'extra cheese']
if 'mushrooms' in requested_toppings:
    print("Adding mushrooms.")
elif 'pepperoni' in requested_toppings:
      print("Adding pepperoni.")
elif 'extra cheese' in requested_toppings:
     print("Adding extra cheese.")
print("\nFinised making your pizza!")
alien_color ='green'
if alien_color == 'green':
   print("Player just earned 5 points!")
alien_color = 'red'
if alien_color == 'green':
   print("Player just earned 5 points!")
alien_color = 'green'
if alien_color == 'green':
   print("Player just earned 5 points for shooting the green alien!")
elif alien_color == 'yellow':
     print("Player just earned 10 points for shooting the yellow alien!")
else:
    print("Player just earned 15 points for shooting the red alien!")
alien_code = 'green'
if alien_color == 'green':
   print("Player just earned 5 points for shooting the green alien!")
else:
    print("Player just earned points for shooting the alien, but its color is not green.")
alien_color = 'red'
if alien_color == 'green':
   print("Player just earned 5 point for shooting the green alien!")
elif alien_color == 'yellow':
     print("Player just earned 10 points for shooing the yellow alien!")
else:
    print("Player just eanred 15 points for shooting the alien, but its color is not green.")
alien_color = 'yellow'
if alien_color == 'green':
   print("Player just earned 5 points for shooting the green alien!")
alien_color = 'yellow'
if alien_color == 'green':
   print("Player just earned 5 points for shooting the green alien!")
elif alien_color == 'yellow':
     print("Player just eanred 10 points for shooting the yellow alien!")
else:
     print("Player just eanred 15 points for shooting the red alien!")
#Version 1 - Green Alien:
alien_color = 'green'
if alien_color == 'green':
   print("Player just earned 5 points for shooting the green alien!")
elif alien_color == 'yellow':
   print("Player just eanred 10 points for shooting the yellow alien!")
else:
    print("Player just earned 15 points for shooting the red alien!")
#Version 2 - Yellow Alien:
alien_color = 'yellow'
if alien_color == 'green':
   print("Player just earned 5 points for shooting the green alien!")
else:
    print("Player just eanred 15 points for shooting the red alien!")
#Version 3 -Red Alien:
alien_color = 'red'
if alien_color == 'green':
   print("Player just eanred 5 points for shooting the green alien!")
elif alien_color == 'yellow':
     print("Player just eanred 10 points for shooting for shooting for shooting the yellow alien!")
else:
     print("Player just earned 15 points for shooting the red alien!")
age = 1
if age < 2:
   print("The person is a baby.")
elif age < 18:
   print("The person is a child.")
elif age < 65:
     print("The person is a adult.")
else:
     print("The person is a senioir.")
age = 3
if age < 2:
   print("The person is a baby.")
elif age >=2 and age < 4:
     print("The person is a toddler.")
elif age < 18:
     print("The person is a child.")
elif age < 65:
     print("The person is an adult.")
else:
     print("The person is a senior.")
age = 7
if age < 2:
   print("The person is a baby.")
elif age >=2 and age < 4:
     print("The person is a toddler.")
elif age >=4 and age < 13:
     print("The person is a kid.")
elif age < 65:
     print("The person is an adult.")
else:
     print("The person is a senior.")
age = 16
if age < 2:
   print("The person is a baby.")
elif age >= 2 and age < 4:
     print("The person is a toddler.")
elif age >=4 and age < 13:
     print("The person is a kid.")
elif age >=13 and age < 20:
     print("The person is a teenager.")
elif age < 65:
     print("The person is an adult.")
else:
     print("The person is a senior.")
age = 30
if age < 2:
   print("The person is a baby.")
elif age >= 2 and age <4:
    print("The person is a toddler.")
elif age >= 4 and age < 13:
     print("The person is a kid.")
elif age >= 13 and age < 20:
     print("The person is a teenager.")
elif age >= 20 and age < 65:
     print("The person is an adult.")
else:
     print("The person is an adult.")

print("The person is a senior.")
age = 70
if age < 2:
   print("The person is a baby.")
elif age >= 2 and age < 4:
     print("The person is a toddler.")
elif age >= 4 and age <13:
     print("The person is a kid:")
elif age >=13 and age < 20:
     print("The person is ateenager.")
elif age >= 20 and age < 65:
     print("The person is an adult.")
else:
     print("The person is an elder.")
requested_toppings = ['mushrooms' , 'green peppers' , 'extra cheese']
for requested_topping in requested_toppings:
    print(f"Adding{requested_topping}.")
print("\nFinished making your pizza!")
requested_toppings = ['mushrooms' , 'green pepers' , 'extra cheese']
for requested_topping in requested_toppings:
    if requested_topping == 'green peppers':
       print("Sorry, we are not of green peppers right now.")
else:
     print(f"Adding{requested_topping}.")
print("\nFinished making your pizza!")
requested_toppings = []
if requested_toppings:
   for requested_topping in requested_toppings:
       print(f"Adding{requested_topping}.")
       print("\nFinised making your pizza!")
else:
     print("Are you sure you want a plain pizza?")
available_toppings = ['mushroom' , 'olives' , 'green peppers' , 'pepperoni' , 'pineapple' , 'extra cheese']
requested_toppings = ['mushroom' , 'french fires' , 'extra cheese']
for requested_topping in requested_toppings:
    if requested_topping in available_toppings:
       print(f"Adding{requested_topping}.")
    else:
        print(f"sorry, we don't{requested_topping}.")
print('\nFinised making your pizza!')
username = ['admin' , 'john_doe' , 'sarah_smith' , 'coolgamer123' , 'admin2020']
for username in username:
  if username == 'admin':
     print("Hello admin, would you like to see a status report?")
else:
     print("Hello" + username + "welcome back!")
username = ['admin' , 'jaden_smith' , 'lisa_jones' , 'max_power' , 'admin_007']
for username in username:
   if username == 'admin':
     print("Hello admin, welocme back!")
else:
     print("Hello" + username + ",thank you for logging in again.")
username = ['admin' , 'jaden_smith' , 'lisa_jones' , 'max_power' , 'admin_007']
if username:
  for username in username:
    if username == 'admin':
       print("Hello" + username + ",thank you for logging in again.")
else:
     print("We need to find some users!")

print("We need to find some users!")
usernames = []
if username in username:
   if username == 'admin':
     print("Hello admin, welocme back!")
else:
    print("Hello" + username + ",thank you for logging in again.")

    print("We need to find some user!")
#List of current users
current_users = ['john_doe' , 'sarah_smith' , 'coolgamer123' , 'admin2020' , 'emma_watson']
#List of new users to be checked for uniqueness
new_users = ['john_doe' , 'lisa_jones' , 'brad_pitt' , 'sarah_smith' , 'michael_jordan']
#Check uniqueness of new usernames againist current users:
for new_user in new_users:
    if new_user.lower() in [user.lower() for user in current_users]:
       print(f"Sorry, the username'{new_user}' is already taken. Please choose a different username.")
else:
     print(f"The username'{new_user}' is available. You can procced with registration.")
#List of current users
current_users = ['john_doe' , 'sarah_smith' , 'coolgamer123' , 'admin2020' , 'emma_waston']
#list of new users to be checked for uniqueness
new_user = ['john_doe' , 'lisa_jones' , 'brad_pitt' , 'sarah_smith' , 'michael_jordan']
#Check uniqueness of new usernames against current users
for new_user in new_users:
    if new_user.lower() in [user.lower() for user in current_users]:
     print(f"The username'{new_user}' is not avaiable. Please choose a different username.")
else:
     print(f"The username '{new_user}' is available. You can proceed with registration.")
#List of current users
current_users = ['John_doe' ,  'sarah_smith' , 'coolgamer123' , 'admin2020' , 'emma_watson']
#Convert all current username to lowercase

current_users_lower=[user.lower() for user in current_users]
#List of new users to be checked for uniquness
new_user=['John' , 'lisa_jones' , 'BRAD_pitt' , 'Sarah_Smith' , 'Michael_Jordan']
#Check uniquneness of new usernames against current users
for new_user in new_users:
    if new_user.lower() in current_users_lower:
       print(f"The username'{new_user}' is not not available. Please choose a different username.")
else:
    print(f"The username'{new_user}' is available. You can proceed with registration.")
numbers = list(range(1,10))
for number in numbers:
   if number == 1:
      print(f"{number}st")
   elif number == 2:
      print(f"{number}nd")
   elif number == 3:
      print(f"{number}rd")
   else:
       print(f"{number}th")
number = list(range(1,10))
for number in number:
    if number == 1:
      ordinal = "1st"
    elif number == 2:
       ordinal = "2nd"
    elif number ==3:
      print(ordinal)
numbers = list(range(1,10))
for number in numbers:
    if number == 1:
      ordinal = '1st'
    elif number == 2:
      ordinal = "2nd"
    elif number == 3:
      ordinal = "3rd"
    else:
      ordinal = str(number) + "th"
    print(ordinal)
x = 10
if (x>5) and (x<15):
   print("x is betwwen 5 and 15")
numbers = [3,-5, 7, -2, 8]
sum_of_numbers = sum(numbers)
if sum_of_numbers < 0:
   print("The sum of the number is positve.")
# Out:
# Audi
# BMW
# Subaru
# Toyota
# Holding the anhovies!
# That is not the correct
# Marie, you can post a resqonse if you wish.
# Is car == 'subaru' I pedict True.
# True
#
# Is car == 'audi'? I predict False.
# False
# Test 1: Is x equal to 5?
# True
# Test 2: is y not equal to 10?
# False
# Test 3: Is x less than y?
# 5 10
# Test 4: Is y greater than or equal to 10?
# True
# Test 5: Is x greater than y?
# False
# Test 1: Is a equal to 10?
# True
# Test2: Is b not equal to 10?
# True
# Test 3: Is c less than b?
# True
# Test 4: Is d greater than or equal to 10?
# True
# Test5: Is e less than b?
# True
# Test6: Is a not equal to 10?
# False
# Test 7: Is b equal to 20?
# True
# Test 8: Is c greater than or equal to 10?
# False
# Test 9: Is d less than a?
# False
# False
# Test 11: Is string equal to 'hello?'
# False
# Test 12: Is string2 not equal to 'hello'?
# True
# Test 13: Is string1 equal to string3?
# True
# Test14: Is string2 equal to 'world?
# False
# True
# ...
