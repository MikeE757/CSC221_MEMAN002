# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeE757/CSC221_MEMAN002/blob/main/Chapter8Assignment9_py(New).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet_user():
  print("Hello!")
greet_user()

def greet_user(username):
  print(f"Hello, {username.title()}!")
  greet_user('Jesse')

def favorite_book(title):
    message = f"One of my favorite books {title}."
    print(message)

favorite_book("Alice in wounderland")

def describe_pet(animal_type, pet_name):
  print(f"\nI have a{animal_type}.")
  print(f"My{animal_type}'s name is {pet_name.title()}.")
  describe_pet('hamester' , 'harry')

def describe_pet(animal_type ,pet_name):
    print(f"\nI have a {animal_type}.")
    print(f"My{animal_type}'s name is {pet_name.title()}.")
describe_pet('hamster' , 'harry')
describe_pet('dog' , 'Willie')

def describe_pet(animal_type , pet_name):
    print(f"\nI have a {animal_type}.")
    print(f"My{animal_type}'s{pet_name.title()}.")

describe_pet(animal_type='hamster' , pet_name='harry')
describe_pet(pet_name='harry' , animal_type='hamster')

def describe_pet(animal_type , pet_name):
  print(f"\nI have a {animal_type}.")
  print(f"My {animal_type}'s name is {pet_name.title()}.")

def make_shirt(size , message):
    summary = f"The shirt size is {size} and the message printed on its: '{message}.'"
    print(summary)

def make_shirt(size="large" , message="love Python"):
  summary = f"The shirt is {size} and the mnessage printed on it is:'{message}'."
  print(summary)
  make_shirt()
  make_shirt(size="medium")
  print(size)

def describe_city(city, country="Unknown"):
  sentence = f"{city} is in {country}."
  print(sentence)
  describe_city("Reykjavik" , "Iceland")
  describe_city("Paris" , "France")
  describe_city("Tokyo")

def get_formatted_name(first_name , last_name):
  full_name = f"{first_name , {last_name}}"
  return full_name.title()
musician = get_formatted_name('jimi' , 'hendrix')
print(musician)

def get_formatted_name(first_name , middle_name , last_name):
  full_name = f"{first_name} {middle_name} {last_name}"
  return full_name.title()
musician = get_formatted_name('John' , 'Lee' , 'Hooker')
print(musician)

def get_formnatted_name(first_name , last_name , middle_name=''):
    if middle_name:
      full_name = f"{first_name} {middle_name} {last_name}"
    else:
        full_name = f"{first_name} {last_name}"
        musician = get_formatted_name('Jimi' , 'Hendrix')
print(musician)
musician = get_formatted_name('John' , 'Hooker' , 'Lee')
print(musician)

def build_person(first_name , last_name):
    person = {'first': first_name , 'last': last_name}
    return person
musician = build_person('Jimi' , 'Hendrix')
print(musician)

def build_person(first_name , last_name , age = None):
    person = {'first': first_name , 'last': last_name}
    if age:
          person['age'] = age
    return person
musician = build_person('Jimi' , 'Hendrix' , age=27)
print(musician)

def get_formnatted_name(first_name , last_name):
  full_name = f"{first_name} {last_name}"
  return full_name.title()
while True:
      print("\nPlease tell me your name:")
f_name = input("First namme:")
get_formatted_name

def get_formatted_name(first_name , last_name):
  full_name = f"{first_name} {last_name}"
  return full.title()
while True:
      print("\nPlease tell me your name:")
      print("(enter 'q' at any time to quit)")
      f_name = input("First name:")
      if f_name == 'q':
          break
      l_name = input("Last name:")
      if l_name == 'q':
          break
      formatted_name = get_formatted_name(f_name , I_name)
      print(f"\nHello, {formatted_name}!")

("enter 'q' at any time to quit")

def city_country(city , country):
    formate_string = f"{city.title()} , {country.title()}"
    return get_formatted_string

def make_album(artist , tilte):
    album = {'artist': artist , 'title': title}
    return album
album1 = make_album('Jay-Z','The Black Album')
album2 = make_album('Beyonce','Lemonade')
album3 = make_album('Puff Daddy','Press Play')
print(album1)
print(album2)
print(album3)

def make_album(artist , tittle):
    album = {"artist": artist, "title": title}
    return album
while True:
      print("\Enter 'q' at any time to quit.")
      artist_name - input("Enter the artist name:")
      if artist_name == 'q':
          break
      album_title = input("Enter the album title:")
      if album_title == 'q':
          break
      album_info = make_album(artist_name , album_title)
      print(album_info)


def greet_user(name):
    for name in names:
        msg = f"Hello , {name.title()}!"
        print(msg)
username = ['Hannah' , 'Try' , 'Margot']
greet_user(usernames)

while uprinted_designs:
      current_design = unprinted_designs.pop()
      print(f"Printing model: {current_design}")
      completed_model.append(current_design)
def show_completed_model(completed_models):
     print("\nThe following models have been printed:")
     for completed_model in completed_models:
         print(completed_model)
unprited_designs = ['Phone case' , 'Robot pendant' , 'Dodecahedron']
completed_models = []
print_models(unprinted_designs , completed_models)
show_completed_models(show_completed_models)

def show_message(messages):
    for message in messages:
        print(message)
message_list = ["Hello , how are you?" , "Don't forget to pick up milk." , "Remember: Meeting at 2PM." , "Happy birthday!" , "See you tomorrow!"]

def send_mesaage(messages , sent_messages):
    while messages:
      current_message = messages.pop(0)
      print("Sending message." , current_message)
sent_message.append(current_message)
message_list = ["Hello , how are you?" , "Don't forget to pick up milk." , "Reminder: Meeting at 2PM." , "Happy birthday!" , "See you tomorrow!"]
sent_message_list =[]
send_message(message_list, sent_message_list)
print("Original messages:" , sent_message_list)
print("Sent messages:" , sent_message_list)

def send_mesaage(message, sent_message):
    while messages:
        current_message = messages.pop(0)
        print("Sending message:" , current_message)
    sent_message.append(current_message)
message_list = ["Hello , how are you?" , "Don't forget to pick up milk." , "Reminder: Meeting at 2PM." , "Happy birthday!" , "See you tomorrow!"]
message_list_copy = message_list[:]
sent_message_list = []
send_message(message_list_copy , sent_message_list)
print("Original message:" , message_list)
print("Sent message:" , sent_message_list)

def make_pizza(*toppings):
  print(toppings)
make_pizza('Pepperoni')
make_pizza('mushroom' , 'Green peooper' , 'Extra Cheese')

def make_pizza(*toppings):
  print("\Making a walking a pizza with the following toppings:")
  for topping in toppings:
      print(f"- {topping}")
make_pizza('Pepperoni')
make_pizza('mushrooms' , 'Green peppers' , 'Extra Cheese')

def make_pizza(size,toppings):
    print(f"\nMaking a {size}-inch pizza with the follwing toppings:")
    for topping in toppings:
      print(f" - {topping}")
make_pizza(16 , 'pepperoni')
make_pizza(12 , 'mushrooms' , 'Green peppers' , 'Extra Cheese')


def build_profile(first , last , user_info):
    user_info['first_name'] = first
    user_info['last_name'] = last
    return user_info
user_profile = build_profile('Albert' , 'Einstein' , location = 'Princetion' , filed = 'physics')
print(user_profile)

def make_sanwich(*items):
    print("Making a sanwhich with the following items:")
    for item in items:
      print("-" + item)
    print("Enjoy your sanwich!\n")
    make_sandwich("Ham" , "Cheese")
    make_sandwich("Peanut Butter" , "Jelly" , "Banna" , "Honey")

def build_profile(first_name , last_name , **kwargs):
    profile = {}
    profile['first_name'] = 'first_name'
    profile['Last_name'] = 'Last_name'
    for key , value in kwargs.items():
        profile[key] = value
    return profile
user_profile = build_profile("John" , "Doe" , age=30 , occupation = "Software Engineer" , hobbies=["Reading" , "Coding"])
print(user_profile)

def car_info(manufacturer , model , **kwargs):
    car = {'manufacturer': manufacturer , 'model': model}
    car.update(kwargs)
    return car

    car1 = car_info('Toyota' , 'Canmry' , color='blue' , year=2022)
    print(car1)
    car2 = car_info('Tesla' , 'Model S' , color='red' , autopilot =True,price=8000)
    print(car2)

    def make_pizza(size , *toppings):
        print(f"\nMaking a {size}-inch pizza with the following toppings:")
        for topping in toppings:
            print(f"-{topping}")

import pizza as p
p.make_pizza(16 , 'Pepperoni')
p.make_pizza(12 , 'Mushrooms' , 'Green Peppers' , 'Extra Cheese')
from pizza import*
make_pizza(16 , 'peppernoni')
make_pizza(12 , 'Mushrooms' , 'Green peppers' , 'Extra Cheese')

def function_name(parameter_0 , parameter_1, parmeter_2, parmeter_3 , parmeter_4 , parameter_5):
  print(f"Printing model: {model_name}")
def apply_finish(model_name):
    print(f"Printing model:{model_name}")
def apply_finish(model_name , finish_type):
    print(f"Applying{finish_type} finish to model:{model_name}")

    from Printing_function import print_model , apply_finsih
    model = 'Rocket'
    print_model(model)
    finish = 'Matte'
    apply_finish(model , finish)
def print_model(model_name):
  print(f"Printing model:{model_name}")
def greet(name):
  print(f"Hello,{name}!")

def calucate_rectangle_area(length , width):
  area = length * width
  return area

def calculate_sum_and_sorted_numbers(number1 , number2 = 0):
  numbers = [number1 , number2]
  sum_of_numbers = sum(numbers)
  sorted_numbers = sorted(numbers)
  return sum_of_numbers,sorted_numbers

result1 = calculate_sum_and_sorted_numbers(5,3)
print(result)
result2 = calculate_sum_and_sort_numbers(-7,4)
print(result2)
result3 = calculate_sum_and_sort_number(-10,-2)
print(result3)
result4 = calculate_sum_and_sort_number(0,9)
print(result4)
result5 = calculate_sum_and_sort_number(6)
print(result5)
result6 = calculate_sum_sort_number(0,0)
print(result6)

def calculate_sum_and_sorted_(numbers1 , number2 = math.pi,verbose = False):
  numbers=(number1 , number2)
sum_of_numbers=sum(numbers)
sorted_numbers=sorted(numbers)
if verbose:
   print(f"Number1:{Number1}")
   print(f"Number2:{Number2}")
{sum_of_numbers}
print(f"Sorted numbers:{sorted_numbers}")
return sum_of_numbers , sorted_numbers
# Out:
# Streaming output truncated to the last 5000 lines.
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# Please tell me your name:
#
# ...
