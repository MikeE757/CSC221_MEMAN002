# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeE757/CSC221_MEMAN002/blob/main/Assignment8_Crash_Chapter_8_Function1%2CPart1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet_user(username):
    print(f"Hello,{username.title()}!")
def display_message():
    print("In this chapter, we are learning about function in Python.")
#Call the function to display the message display_message()
def favorite_book(title):
    print(f"One of my favorite book is title.")
#Call the function with a book title
favorite_book("Alice in Wounderland")
def describe_pet(animal_type,pet_name):
    print(f"\nI have a {animal_type}.")
    print(f"My animal_type name is {pet_name.title}.")
def describe_pet(animal_type,pet_name):
    print(f"\nI have a {animal_type}.")
    print(f"My{animal_type}'s name is {pet_name.title()}.")
describe_pet('hamster' , 'harry')
describe_pet('dog', 'willie')
def describe_pet(animal_type,pet_name):
    print(f"\nI have a {animal_type}.")
    print(f"My{animal_type}'s name is {pet_name.title()}.")
describe_pet('harry','hamster')
def describe_pet(animal_type,pet_name):
    print(f"\nI have a {animal_type}.")
    print(f"My{animal_type}'s name is {pet_name.title()}.")
describe_pet(animal_type='hamster',pet_name='harry')
describe_pet(animal_type='harry',pet_name='harry')
describe_pet(pet_name='harry',animal_type='hamster')
def describe_pet(pet_name,animal_type='dog'):
    print(f"\nI have a {animal_type}.")
    print(f"My{animal_type}'s name is {pet_name.title()}.")
describe_pet(pet_name='willie')
describe_pet('willie')
describe_pet(pet_name='harry',animal_type='hamster')
def describe_pet(animal_type,pet_name):
    print(f"\nI have a {animal_type}.")
    print(f"My{animal_type}'s name is {pet_name.title()}.")
def make_shirt(size,message):
    print(f"Creating a{size}t-shirt with message:{message}")
#Call the function using positional arguments make_shirt("M" , "Hello, World!")
#Call the function using keyword arguments make_shirt(size="L",message="Python Rocks!")
def make_shirt(size="L",message="I love Python"):
    print(f"Creating a {size} t-shirt with the message:'{message}")
#Create a large shirt with the default message
make_shirt()
#Create a meduim shirt with the default mesaage
make_shirt(size="M")
#Create a shirt of any size with a different message
make_shirt(size="S", message="Keep Calm and Code On")
def describe_city(city,country="Unknown"):
    print(f"{city} is in {country}")
#Call the function for three different citites
describe_city("Reykjavik","Iceland")
describe_city("Paris","France")
describe_city("Tokyo","Japan")
def get_formatted_name(first_name,last_name):
    full_name = f"{first_name}{last_name}"
    return full_name.title()
musician = get_formatted_name('jimi' , 'hendrix')
print(musician)
def get_formatted_name(first_name,middle_name,last_name):
    full_name = f"{first_name}{middle_name}{last_name}"
    return full_name.title()
musician = get_formatted_name('john' , 'lee' , 'hooker')
print(musician)
def get_formatted_name(first_name,last_name,middle_name=''):
    if middle_name:
       full_name = f"{first_name}{middle_name}{last_name}"
    else:
       full_name = f"{first_name}{last_name}"
    return full_name.title()
musician = get_formatted_name('jimi' , 'hendrix')
print(musician)
def build_person(first_name,last_name):
   person = {'first': first_name, 'last' : last_name}
   return person
def build_person(first_name,last_name,age=None):
    person = {'first': first_name, 'last' : last_name}
    if age:
         person['age'] = age
    return person
musician = build_person('jimi' , 'hendrix' , age=27)
print(musician)
def get_formatted_name(first_name,last_name):
    full_name = f"{first_name}{last_name}"
    return full_name.title()
while True:
     print("\nPlease tell me your name:")
     f_name = input("First name:")
     l_name = input("Last name:")
     formatted_name = get_formatted_name(f_name, l_name)
     print(f"\nHello,{formatted_name}!")
def get_formatted_name(first_name,last_name):
    full_name = f"{first_name}{last_name}"
    return full_name.title()
while True:
     print("\nPlease tell me your name:")
     print("(enter 'q' at my time to quit)")
     f_name = input("First name:")
     if f_name == 'q':
        break
     l_name = input("Last name:")
     if l_name == 'q':
         break
     formatted_name = get_formatted_name(f_name,l_name)
     print(f"\nHello,{formmated_name}!")
def city_country(city, country):
    return f"{city.title()},{country.title()}"
#Test the function with different city and country combinations
    print(city_country("Paris","France"))
    print(city_country("Tokyo","Japan"))
    print(city_country("New York City","United States"))
def make_album(artist,title,num_songs=None):
    album = {"artist": artist, "title" : title}
    if num_songs:
       album["num_songs"] = num_songs
    return album
#Create three dictionaries representing different albums
album1 = make_album("Taylor Swift" , "1989")
album2 = make_album("Ed Sheeran" , "Divide" , 12)
album3 = make_album("Beyonce", "Lemonade" , 14)
#Print each dictionary to show the album information
print(album1)
print(album2)
print(album3)
def make_album(artist,title,num_songs=None):
    album = {"artist": artist, "title" : title}
    if num_songs:
       album["num_songs"] = num_songs
    return album
while True:
    artist = input("Enter the artist of the album(or 'quit' to exit):")
    if artist.lower() == 'quit':
       break
    title = input("Enter the title of the album:")
    album = make_album(artit,title)
    print(album)
def greet_users(names):
    album = {"artist": artist, "title" : title}
    if num_songs:
       album["num_songs"] = num_songs
    return album
while True:
     artist = input("Enter the artist of the album(or 'quit' to exit):")
     if artist.lower() == 'quit':
       break
     title = input("Enter the title of the album:")
     album = make_album(artist,title)
     print(album)
def greet_user(names):
    for name in names:
        msg = f"Hello,{name.title()}!"
        print(msg)
usernames = ['hannah' , 'ty' , 'margot']
greet_user(usernames)
while unprinted_designs:
      current_design = unprinted_designs.pop()
      print(f"Printing model:{current_designs}")
      completed_models.append(current_design)
      print("\nThe following models have been printed:")
      for completed_model in completed_models:
          print(completed_model)
while unprinted_designs:
      current_design = unprinted_design.pop()
      print()
def show_completed_models(completed_models):
      print("\nThe following models have been printed:")
      for completed_model in completed_models:
          printed(completed_model)
unprinted_designs = ['phone case' , 'robot pendant' , 'dodecahdron']
completed_models = []
print_models(unprinted_designs, completed_models)
show_completed_models(completed_models)
unprinted_designs = ['phone case' , 'robot pendant' , 'dodecahdron']
completed_models = []
print_models(unprinted_designs,completed_models)
show_completed_models(completed_models)
def show_message(message):
    for message in messages:
       print(message)
#Define a list of text message
messages = ["Hello! How are you?", "Don't forget to buy milk on your way home.", "Meeting at 3 PM today. Don't be late!","Hope you have a great day!","Remember to call your mom later."]
#Call the function to show the message
show_messages(messages)
def semd_message(message,sent_message):
    while messages:
      current_message = message.pop(0)
      print(current_message)
sent_message.append(current_message)
#Define a list of text message
messages = ["Hello! How are you?," "Don't forget to buy milk on your way home." , "Hope you have a great mom later."]
sent_messages = []
#Call the function to send messages
send_messages(messages,sent_messages)
#Print both lists to make sure the messages were moved correctly
print("\nSent messages:")
for message in messages:
    print(message)
    print("\nSent message:")
for message in messages:
    print(message)
def send_messages(message,sent_messages):
    while messages:
     current_message = message.pop(0)
print(current_message)
sent_messages.append(current_message)
def make_pizza(toppings):
    print(toppings)
make_pizza('pepperoni')
make_pizza('mushrooms','green peppoers','extra cheese')
def make_pizza(toppings):
    print("\nMaking a pizza with the following toppings:")
for topping in toppings:
    print(f"-{topping}")
make_pizza('pepperoni')
make_pizza('mushroom','green peppers' , 'extra cheese')
def make_pizza(size, toppings):
    print(f"\nMaking a {size}-inch pizza with the following toppings:")
for topping in toppings:
    print(f"-{topping}")
make_pizza('pepperoni')
make_pizza('mushrooms','green peppers','extra cheese')
def make_pizza(size,topping):
    print(f"\nMaking a {size}-inch pizza with the following toppings:")
    for topping in toppings:
        print(f"-{topping}")
make_pizza(16,'pepperoni')
make_pizza(12,'mushroom','green peppers','extra cheese')
def build_profile(first,last,user_info):
    user_info['first_name'] = first
    user_info['last_name'] = last
    return user_info
user_profile = build_profile('albert','einstein' , location = 'princeton' , filed = 'physics')
print(user_profile)
def make_sandwich(ingredients):
    print("Making a sandwich with the following ingredients:")
    for ingreddient in ingredients:
     print("-" + ingredient)
     print("Enjoy your sandwich!\n")
#Call the function with different number of arguments
make_sandwich("Turkey", "Lettuce" , "Tomato" , "Mayonnaise")
make_sandwich("Ham","Cheese")
make_sandwwich("Peanut Butter" , "Jelly")
def make_sandwich(ingredients):
    print("-" + ingredient)
    print("Enjoy your sandwich!\n")
def build_profile(first_name,last_name,user_info):
    profile = {}
    profile['first_name'] = first_name
    profile['last_name'] = last_name
    for key, value in user_info.items():
        profile[key] = value
    return profile
# Build a profile of yourself
my_profile = build_profile('john' , 'Doe' , location='Cailfornia' , occupation = 'Software Engineer', hobby='Playing guitar')
print(my_profile)
def car_info(manufacturer,model):
    car = {}
    car['manufactuer'] = manufactuer
    car['model'] = model
    for key, value in kwargs.items():
        car[key] = value
    return car
#Call the function with required information and additional details
car_data = car_info('Toyota' , 'Corolla' , color='blue',year=2023)
print(car_data)
def make_piza(size,toppings):
    print(f"\Making a {size}-inch pizza with the following")
    for topping in toppings:
        print(f"-{topping}")
# Out:
# One of my favorite book is title.
#
# I have a hamster.
# Myhamster's name is Harry.
#
# I have a dog.
# Mydog's name is Willie.
#
# I have a harry.
# Myharry's name is Hamster.
#
# I have a hamster.
# Myhamster's name is Harry.
#
# I have a harry.
# Myharry's name is Harry.
#
# I have a hamster.
# Myhamster's name is Harry.
#
# I have a dog.
# Mydog's name is Willie.
#
# I have a dog.
# Mydog's name is Willie.
#
# I have a hamster.
# Myhamster's name is Harry.
# Creating a L t-shirt with the message:'I love Python
# Creating a M t-shirt with the message:'I love Python
# Creating a S t-shirt with the message:'Keep Calm and Code On
# Reykjavik is in Iceland
# Paris is in France
# Tokyo is in Japan
# Jimihendrix
# Johnleehooker
# Jimihendrix
# {'first': 'jimi', 'last': 'hendrix', 'age': 27}
#
# Please tell me your name:
