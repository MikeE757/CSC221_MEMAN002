# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeE757/CSC221_MEMAN002/blob/main/Copy_of_Assignment3_Ipynb(New_semester).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Python World!")
message = "Hello Python World!"
print(message)
message = "Hello Python Crash Course World!"
print(message)
message = "This is a simple message."
print(message)
name = "John"
message = f"Hello,{name}!How are you today?"
print(message)
quote = "Be yourself; everyone else is already taken."
author = "Oscar Wilde"
print(f"{quote}-{author}")
quote = "The greatest glory in living lies not in never falling, but in rising every time we fall."
author = "Nelson Mandela"
message = "Hello,World!"
message = "Hello , World!"
print(message)
message = "Hello , World!"
print(message)
message = "Welcome to Python"
print(message)
name = "ada lovelace"
print(name.title())
name = "Ada Lovelace"
print(name.upper())
print(name.lower())
first_name = "ada"
last_name = "lovelace"
full_name = f"{first_name}{last_name}"
print(full_name)
first_name = "Ada"
last_name = "Lovelace"
full_name = f"{first_name}{last_name}"
print(full_name)
first_name = "ada"
last_name = "lovelace"
full_name = f"{first_name}{last_name}"
print(f"Hello,{full_name.title()}!")
first_name = "ada"
last_name = "lovelace"
full_name = f"{first_name}{last_name}"
message = f"Hello,{full_name}"
print("Python")
print("\tPython")
print("Languages:\nPython\c\nJavaScript")
print("Languages:\n\tPython\n\tc\ntJavaScipt")
favorite_language = 'Python'
favorite_language
favorite_language.rstrip()
favorite_language
favorite_language.lstrip()
favorite_language.strip()
nostarch_url = 'https://nostarch.com'
nostarch_url.removeprefix('hhts://')
'nostarch.com'
simple_url = nostarch_url.removeprefix('https://')
message = "One of Python's strengths is its diverse community."
print(message)
name = "Eric"
message = "Hello" +name+"would you like to learn some Python today?"
print(message)
name = "John Doe"
#Lowercase
print(name.lower())
#Uppercase
print(name.upper())
#Titlecase
print(name.title())
print("The only way to do great work is to love what you do, -Steve Jobs")
famous_person = "Steve Jobs"
print("The only way to do great work is to love what you do, -Steve Jobs")
name = "\t John Doe\n"
print(f"Original Name:{name}")
print(f"Lstrip Name:{name.lstrip()}")
print(f"Rstrip Name:{name.rstrip()}")
print(f"Strip Name:{name.strip()}")
2+3
3-2
2*3
3/2
3**2
3**3
10**6
(2+3)*4
2+3*4
0.1+0.1
0.2+0.2
2*0.1
2*0.2
0.2+0.1
3.0*0.1
4/2
1+2.0
2*3.0
3.0**2
universe_age = 14,000,00,000
print(universe_age)
x,y,z = 0,0,0
MAX_CONNECTIONS = 50000
print(5+3)
print(10-2)
print(4*2)
print(16/2)
favorite_number = 7
message = f"My favorite is {favorite_number}."
print(message)
#say hello to everyone.
print("Hello Python people!")
#Program 1: Addition
#Program wirtten by Michael Emanuel
#Date: 2024-02-08
#This program perform addition and prints the result.
print(5+3)#Addition:5+3
