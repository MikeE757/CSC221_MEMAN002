# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeE757/CSC221_MEMAN002/blob/main/ch2_assignment3_ipynb_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
message = "Hello python world"
print(message)

message ="Hello python world!"
print("Hello python Crash Course world!")
print("message")

message = "Hello python Crash Course reader!"
print(message)

message = "One of python's strengths is its diverse community."
print(message)

message = "Hello , world!"
print(message)

message = "Welcome to prgramming world!"
print(message)

name = "Eric"
message = f"Hello{name},would you like to learn some Python today?"
print(message)

person_name = "john doe"
print(person_name.lower())
print(person_name.lower())
print(person_name.upper())
print(person_name.title())


name = "\tJohn Doe\n"
print("Using lstrip():", name.lstrip())
print("Using rstrip():", name.rstrip())


filename = 'python_notes.txt'
file_without_extension = filename.split('.')[0]
print(file_without_extension)

2+3

3-2

2*3

3/2

3**2

3**3

10**6

2+3*4

(2+3)*4

0.1+0.1

0.2+0.2

2*0.1

2*0.2

0.2+0.1

3*0.1

4/2

1+2.0

2*3.0

3.0**2

universe_age = 14_000_000_000
print(universe_age)


print(5+3)
print(10-2)
print(4*2)
print(16/2)

favorite_number=42
print("My favorite number is:", favorite_number)

print("Hello python people!")

def add(a,b):
  return a+b

def subtract(a,b):
  return a-b

def multiply(a,b):
  return a*b

def divide(a,b):
  if b!=0:
    return a/b
  else:
    return"Error:Division by zero is notallowed"
# Out:
# Hello python world
# Hello python Crash Course world!
# message
# Hello python Crash Course reader!
# One of python's strengths is its diverse community.
# Hello , world!
# Welcome to prgramming world!
# HelloEric,would you like to learn some Python today?
# john doe
# john doe
# JOHN DOE
# John Doe
# Using lstrip(): John Doe
#
# Using rstrip(): 	John Doe
# python_notes
# 14000000000
# 8
# 8
# 8
# 8.0
# My favorite number is: 42
# Hello python people!
