# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeE757/CSC221_MEMAN002/blob/main/Assignment5_Crash_Chapter_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
magicians = ['alice' , 'david' , 'carolina']
for magician in magicians:
    print(magician)
for magician in magicians:
    print(magician)
magicicans = ['alice' , 'david' , 'carolina']
for magicicans in magicians:
    print(f"{magician.title}, that was great a great trick!")
magicians = ['alice' , 'david' , 'carolina']
for magician in magicians:
    print(f"{magician.title()}, that a great trick!")
magician = ['alice' , 'david' , 'carolina']
for magician in magicians:
    print(f"{magician.title()}, that was a great trick!")
    print(f"I can't wait to see your next trick,{magician.title()}.\n")
magicians = ['alice' , 'david' , 'carolina']
for magician in magicians:
    print(f"{magician.title()}, that was a great trick!")
    print(f"I can't wait to see your next trick,{magician.title()}.\n")
magicians = ['alice' , 'david' , 'carolina']
for magician in magicians:
    print(f"{magician.title()}, that was great trick!")
    print(f"I can't wait to see your next trick,{magician.title()}.\n")
magicians = ['alice' , 'david' , 'carolina']
for magician in magicians:
    print(magician)
magicians = ['alice' , 'david' , 'carolina']
for magician in magicians:
    print(f"{magician.title()}, that was a great trick!")
print(f"I can't wait to see your next trick,{magician.title()}.\n")
message = "Hello Python world"
print(message)
magicians = ['alice' , 'david' , 'carolina']
for magician in magicians:
    print(f"{magician.title()} , that was a great trick!")
    print(f"I can't wait to see your see next trick,{magician.title()}.\n")
    print("Thank you everyone, that was a great magic show!")
magicians = ['alice' , 'david' , 'carolina']
for magician in magicians:
    print(magician)
#List of favvorite pizza
favorite_pizzas = ['Pepperoni' , 'Margherita' , 'BBQ Chicken']
#Print the name of each pizza using a for a for loop
print("Pizza names")
for pizza in favorite_pizzas:
  print(pizza)
#Print a sentence for each pizza
print("\nSimple statements:")
for pizza in favorite_pizzas:
    print("I like pizza. format(pizza)")
#List of favorite pizzas
favorite_pizzas = ['Pepperoni' , 'Margherita' , 'BBQ Chicken']
#Print the name of each pizza using a for loop
print("Pizza name:")
for pizza in favorite_pizzas:
    print("I like pizza format(pizza)")
#Additional lines about the kind of pizza liked
print("\nAdditional lines:")
print("I love the classic flavor of pepperoni pizza with its savory pepperoni slices.")
print("Margherita pizza with its simple yet delicous combination of tomato, mozzarella, and basil is always a favorite.")
print("BBQ Chicken pizza is a tasty twist with its tangy barbecue sauce, grilled chicken, and melted cheese.")
#Final statement
print("I really love pizza!")
#list of aniamls known for being fast
fast_animals = ['Chesstah' , 'Peregrine Falcon' , 'Sailfish']
#Print each fast animal using a for loop
print("Fast animals:")
for animal in fast_animals:
  print(animal)
#Print each animal using a for loop with a statement
  print("Pet animals:")
#List of animals commonly kept as pets
pet_animals = ['Dog','Cat','Rabbit']
#Print each animal using a for loop with a statement
print("Pet animals:")
for animal in pet_animals:
    print(animal)
#Print a statement for each pet animal
print("\nStatement about pet animals:")
for animal in pet_animals:
    print("A{} would make a great pet.".format)
#List of animals known for their intelligence
intelligent_animals = ['Dolphin','Elephant','Chimpanzee']
#Print each intelligent using a for loop
print("Intelligent animals:")
#Print a statement about what these animals have in common
print("\ncommon characterictic:")
print("Any of these animals would inpress you with their intelligence!")
for value in range(1,5):
    print(value)
for value in range(1,6):
    print(value)
numbers = list(range(1,6))
even_numbers = list(range(2,11,2))
print(even_numbers)
squares = []
for value in range(1,11):
    square = value **2
    squares.append(square)
print(square)
squares = []
for value in range(1,11):
    squares.append(value**2)
print(square)
digits = [1,2,3,4,5,6,7,8,9,0]
min(digits)
max(digits)
sum(digits)
squares=[value**2 for value in range(1,11)]
print(squares)
for i in range(1,21):
    print(i)
#Create a list of numbers from 1 to 1 million
numbers = list(range(1,1000001))
#Check if the list starts at 1 and ends at 1 million using min() and max() functions
print("Minimum number in the list:" , min(numbers))
print("Maximum number in the list:", max(numbers))
#Calculate the sum of the numbers using the sum() function
total_sum = sum(numbers)
print("Sum of numbers from 1 to 1 million:", total_sum)
#Create a list to store the first 10 cubes
cubes = []
#Calcualte and store the cubes of numbers from 1 to 10
for i in range(1, 11):
    cube = i **3
    cubes.append(cube)
#Print out the value of each cube
for cube in cubes:
    print(cube)
#Create a list to store the multiple of 3 from 3 to 30
multiples_of_3 = []
#Calculate and store the multiple of 3 from 3 to 30
for i in range(3,31,3):
    multiples_of_3.append(i)
#Print out the numbers in the list
for num in multiples_of_3:
    print(num)
#Create a list to store the cubes of integers from 1 to 10
cubes = []
#Calculate and store the cubes of numbers from 1 to 10
for i in range(1,11):
    cube = i ** 3
    cubes.append(cube)
#Print out the value of each cube
for cube  in cubes:
    print(cube)
#List comprehension to generate a list of the first 10 cubes
cubes = [i**3 for i in range(1,11)]
#Print out the list of cubes
print(cubes)
players = ['charles' , 'martina' , 'michael' , 'florence' , 'eli']
print(players[0:3])
players = ['charles' , 'martina' , 'michael' , 'florence' , 'eli']
print(players[1:4])
players = ['charles' , 'martina' , 'michael' , 'florence' , 'eli']
print(players[:4])
players = ['charles' , 'martina' , 'michael' , 'florence' , 'eli']
print(players[2:])
players = ['charles','martina','michael','florence', 'eli']
print(players[-3:])
players = ['charles' , 'martina' , 'michael' , 'florence' , 'eli']
print("Here are first three players on my team:")
for player in players[:3]:
    print(player.title())
my_foods = ['pizza' , 'falafel' , 'carrot cake']
friends_foods = my_foods[:]
print("My favorite foods are:")
print(my_foods)
print("\nMy friend's favorite foods are:")
print(friends_foods)
my_foods = ['pizza' , 'falafel' , 'carrot cake']
friends_foods = my_foods[:]
my_foods.append('cannoli')
friends_foods.append('ice cream')
print("My favorite foods are:")
print(my_foods)
print("\nMy friends's favorite foods are:")
print(friends_foods)
my_foods = ['pizza' , 'falafel' , 'carrot cake']
#This doesn't work
friend_foods = my_foods
friend_foods.append('connoli')
friend_foods.append('ice cream')
print('My favorite foods are:')
print(my_foods)
print("\My friend's favorite foods are:")
print(friend_foods)
#Create a list of items
items = ['apple' , 'banana' , 'cherry' , 'date' , 'ederberry' , 'fig']
#Print the orginal list
print("Original list:")
print(items)
#Print the message "The first three items in the list are:"
print("\nThe first three items in the list are:")
#Use a slice to print the first three items in the list
print(items[:3])
#Create a list of items
items = ['apple' , 'banana' , 'cherry' , 'date' , 'elderberry' , 'fig']
#Print the orginal list
print("Orginal list:")
print(items)
#Print the message "Three items from the middle of the list are:"
print("\nThree items from the middle of the list are:")
#Calculate the start index of the middle slice
start_index = len(items)//2-1
#Use a slice to print three items from the middle of the list
print(items[start_index:start_index+3])
#Orginal list of pizzas
my_pizzas = ["Margherita" , "Pepperoni" , "Vegetarian"]
#Make a copy of the list and call it friend_pizza
friend_pizzas = my_pizzas.copy()
#Add a new pizza to the orginal list
my_pizzas.append("Hawalilan")
#Print the original and friend pizza lists
print("My favorite pizzas:")
#Orginal list of pizzas
my_pizzas = ["Marghertita" , "Pepperoni" , "Vegtarian"]
#Make a copy of the list and call it
friend_pizzas
friend_pizzas = my_pizzas.copy()
#Add a new pizza to the orginal list
my_pizzas.append("Hawalian")
#Print the orginal and friend pizza lists
print("\nMy friends favorite pizza:")
print(my_pizzas)
print("\nMy friend's favorite pizzas:")
print(friend_pizzas)
#Original list of pizza
my_pizzas = ["Marghrita" , "Pepperoni" , "Vegetarian"]
#Make a copy of the list and call it
friend_pizzas
friend_pizzas = my_pizzas.copy()
#Add a different pizza to the friend_pizzas lists
friend_pizzas.append("Mushroom")
#Print the orginal and friend pizza lists
print("My favorite pizzas:")
print(my_pizzas)
print("\nMy friend's favorite pizzas:")
print(friend_pizzas)
#Orginal list of pizzas
my_pizzas = ["Marghertia" , "Pepperoni" , "Vegetarian"]
#Make a copy of the list and call it
friend_pizzas
friend_pizzas = my_pizzas.copy()
#Add a different pizza to each list
my_pizzas.append("Hawailan")
friend_pizzas.append("Mushroom")
#Print "My favorite pizzas are:"
print("My favorite pizzas are:")
for pizza in my_pizzas:
    print(pizza)
#Print "My friends favorite pizzas are:"
print("\nMy friends favorite pizzas are:")
for pizza in friend_pizzas:
    print(pizza)
#Define lists of foods
fruits = ["apple" , "banana" , "Orange"]
vegetables = ["carrot" , "broccoli" , "spinach"]
#Print the list of fruits using a for loop
print("List of fruits:")
for fruits in fruits:
    print(fruits)
#Print the list of fruits using a for loop
print("List of fruits:")
for fruits in fruits:
    print(fruits)
#Print the list of vegetable using a for loop
print("\nList of vegetables:")
for vegetables in vegetables:
  print(vegetables)
dimensions = (200,50)
print(dimensions[0])
print(dimensions[1])
dimensions = (200, 50)
for dimensions in dimensions:
    print(dimensions)
dimensions = (200, 50)
print("Orginal dimensions:")
for dimension in dimensions:
    print(dimensions)
dimensions = (400,100)
print("\nModified dimensions:")
for dimension in dimensions:
    print(dimension)
#Define a tuple of five basic foods
foods =('Rice' , 'Chicken' , 'Salad' , 'Pasta' , 'Vegetable')
#Use a for loop to print each food offerend by the restaurant
for food in foods:
    print(food)
#Orginal menu as tuple
menu = ('Spaghetti' 'Salad' , 'Breadsticks' , 'Soup' , 'Cheesecake')
#The resturant replaces two items on the menu
resvised_menu = list(menu)
resvised_menu[1] = 'Caesar Salad'
resvised_menu[3] = 'Ice Cream'
#Print each item on the revised menu using a for loop
for item in resvised_menu:
  print(item)
def calculate_circle_area(radius):
 result = 3.1459 * radius * radius
 return result
def calculate_circle_area(radius):
    result = 3.1459 * radius * radius
    return result
menu = ('Spaghetti' , 'Salad' , 'Breadsticks'  , 'Soup' , 'Cheescake')
revised_menu = list(menu)
revised_menu[1] = 'Caear Salad'
revised_menu[3] = 'Ice Cream'
for item in revised_menu:
    print(item)
menu = ('Spaghetti' , 'Salad' , 'Breadsticks' , 'Soup' , 'Chessecake')
resvised_menu = list(menu)
resvised_menu[1] = 'Casear Salad'
resvised_menu[3] = 'Ice Cream'
for item in resvised_menu:
    print(item)
def greet(name):
    message = "Hello," + name + "!"
def greet(name):
    print(message)
def factorial(n):
    if n < 0:
       return "Factorial is not defind for negative numbers"
    elif n == 0:
      return 1
    else:
      num_list = list(range(1,n+1))
      result = 1
      for num in num_list:
        result *= num
      return result
#Test the factorial function
n = 5
print(f"The factorial of {n} is: {factorial(n)}")
def factorial(n):
    if n < 0:
       return "Factorial is not defind for negative numbers"
    elif n == 0:
       return 1
    else:
        num_list = list(range(1, n+1))
        num_list = [num for num in num_list if num not in[4,13,22]]
        result = 1
    for num in num_list:
        result *=num
    return result
# Test the factorial function
n = 25
factorial_result = factorial(n)
print(f"The factorial of {n} (excluding 4, 13 , and 22) is: {factorial_result}")
