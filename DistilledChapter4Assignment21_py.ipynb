# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeE757/CSC221_MEMAN002/blob/main/DistilledChapter4Assignment21_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def compare(a,b):
    if a is b:
       print('same object')
    if a==b:
      print('same value')
    if type(a) is type(b):
       print('same type')
a = [1,2,3]
b = [1,2,3]
items = list()
if isinstance(items , list):
   items.append(items)
def removeall(items: list , item)-> list:
    return[i for i in items if i !=item]
class mylist(list):
      def removeall(self , val):
          return [i for i in self if i !=val]
items = mylist([5,8,2,7,2,13,9])
x = items.removeall(2)
print(x)
if isinstance(items , (list , tuple)):
   maxval = max(items)
a = 37
b = a
c = []
c.append(b)
del a
b = 42
c[0] = 2.0
a = 37
import sys
sys.getrefcount(a)
7
a = {}
b = {}
a['b'] = b
b['a'] = a
del a
del b
def some_calculation():
    data = create_giant_data_structure()
    del data
a = [1,2,3,4]
b = a
True
b[2] = -100
a
[1,2, -100 ,4]
a = [1,2,[3,4]]
b = list(a)
b is a
False
b.append(100)
b
[1,2,[3,4]]

def Cat(a,b):
    return a+b
    return a + b
result = Cat(2,3)
print(result)

def Cat(a,b):
    if isinstance(a , str) and isinstance(b,int):
       return a + str(b)
    elif isinstance(a , int) and isinstance(b , str):
         return str(a) + b
    else:
        return "Invaild input types."
result = Cat("Hello" , 123)
print(result)#Output "Hello 123"
result = Cat(456, " , world!")
print(result)#Output "Invaild input types."
def Cat(a,b):
    a = str(a)
    b = str(b)
    return a + b
result = Cat("Hello" , 123)
print(result)#Output: "Hello , 123"
result = Cat(456, "world!")
print(result)#Output "456, world!"
result = Cat("Hello" , "world!")
print(result)#Output:"Hello , world!"
def Cat(a ,  b):
   if isinstance(a , str) and isinstance(b , int):
      return a + str(b)
   elif isinstance(a , int) and isinstance(b , str):
        return str(a) + b
   else:
       return "Both values should be a string and int."
