# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeE757/CSC221_MEMAN002/blob/main/Assignment7_Crash_Chapter6_Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from _typeshed import Self
alien_0 = {'color': 'green' , 'points': 5}
print(alien_0['color'])
print(alien_0['points'])
alien_0 = {'color' : 'green' , 'points' : 5}
alien_0 = {'color' : 'green' , 'points' : 5}
alien_0 = {'color' : 'green'}
print(alien_0['color'])
alien_0 = {'color': 'green' , 'points' : 5}
new_points = alien_0['points']
print(f"You just earned{new_points}points!")
alien_0 = {'color' : 'green' , 'points' : 5}
print(alien_0)
alien_0['x_position'] = 0
alien_0['y_position'] = 25
print(alien_0)
{'color': 'green' , 'points' : 5}
{'color': 'green' , 'points' : 5, 'x_position':0 , 'y_position' : 25}
alien_0 = {}
alien_0['color'] = 'green'
alien_0['points'] = 5
print(alien_0)
alien_0 = {'color' : 'green'}
print(f"The alien is{alien_0['color']}.")
alien_0['color'] = 'yellow'
print(f"The alien is now{alien_0['color']}.")
alien_0 = {'x_position' : 0 , 'y_position' : 25 , 'speed' : 'medium'}
print(f"Orginal position: {alien_0['x_position']}")
#Move the alien to the right.
#Determine how far to move the alien based on its current speed.
if alien_0['speed'] == 'slow':\
   x_increment = 1
elif alien_0['speed'] == 'medium':
     x_increment = 2
else:
    #This must be a fast alien.
    x_increment = 3
#The new position is the old position plus the increment.
alien_0['x_position'] = alien_0['x_position'] + x_increment
print(f"New position:{alien_0['x_position']}")
alien_0['speed'] = 'fast'
alien_0 = {'color' : 'green' , 'points' : 5}
print(alien_0)
del alien_0['points']
print(alien_0)
favorite_languages = {'jen' : 'python' , 'sarah' : 'c' , 'edward' : 'python'}
favorite_languages = {'jen' : 'python' , 'sarah' : 'c' , 'edward' : 'python'}
language = favorite_languages['sarah'].title()
print(f"sarah's favorite languages is {language}.")
alien_0 = {'color' : 'green' , 'speed' : 'slow'}
alien_0 = {'color': 'green' , 'speed': 'slow'}
point_value = alien_0.get('points' , 'No point value .')
print(point_value)
#Creating a dictionary to store information about a person
person = {'first_name': 'Alice' , 'last_name': 'Smith' , 'age': 30 , 'city': 'New York'}
#Printing each piece of information stored in the dictionary
print("First Name:" , person['first_name'])
print("Last Name:" , person['last_name'])
print("Age:" , person['age'])
print("City:" , person['city'])
#Dictionary to store people's favorite numbers
favorite_numbers = {'Alice':7 , 'Bob':21 , 'Charile':13 , 'David':3 , 'Eva':8 }
#Print each person's name and their favorite number
for person , number in favorite_numbers.items():
    print(f"{person}'s favorite number is:{number}")
#Creating a Glossary using a Python dictinary
glossary = {'Python:''A popular high-level progtamming language known for its readability and versatility.','Algorithm:''A set of instructionsns or rules designed to solve a specific problem.','Variable:''A named storage location in a program that holds a value.','Function:''A named block of code that performs a specific task.','Loop:''A programming construct that repeats a block of code until a certain condition is met.'}
#Printing each term and its definition in the Glossary
print

#Creating a Glossary using a Python dictionary
glossary = {'Python:' 'A popular high-level programming language known for its readabitity and versatility.', 'Algorithm:' 'A set of instruction or rules designed to solve a specific problem.' , 'Variable:' 'A named storage location in a program that hold a value.', 'Function:' 'A named block of code that perfroms a specific task.' 'Loop:' 'A programming construct that repreats a block of code until a ceratin condition is met.'}
#Printing each word and its meaning with neatly formatted output

user_0 = {'username' : 'efermi' 'first:' 'enrico', 'last:' : 'fermi'}
for key , value in user_0.items():
    print(f"\nkey:{key}")
    print(f"Value:{value}")
favorite_languages = {'jen': 'python' , 'sarah' : 'c' , 'edward' : 'rust' , 'phil' : 'python'}
for name , language in favorite_languages.items():
    print(f"{name.title()}'s favoritve language is {language.title()}.")
favorite_languages = {'jen': 'python' , 'sarah' : 'c' , 'edward' : 'rush' , 'phil': 'python'}
for name , language in favorite_languages.items():
    print(f"{name.title()}'s favorite language is {language.title()}.")
favorite_languages = {'jen':  'python' , 'sarah' : 'c' , 'edward' : 'rust' , 'phil' : 'python'}
for name in favorite_languages.keys():
        print(name.title())
favorite_lanuguages = {'jen' : 'python' , 'sarah' : 'c' , 'edward': 'rust' , 'phil' : 'python'}
for name in sorted(favorite_languages.keys()):
    print(f"{name.title()}, thank you for taking the poll.")
favorite_languages
friends = ['phil' , 'sarah']
for name in favorite_languages.keys():
    print(f"Hi{name.title()}.")
if name in friends:
   language = favorite_languages[name].title()
   print(f"\t{name.title}, I see you love{language}!")
favorite_language = {'jen': 'python' , 'sarah' : 'c' , 'eward' : 'rust' , 'phil' : 'python'}
for name in sorted(favorite_lanuguages.keys()):
    print(f"{name.title()}, thank you for taking the poll.")
favorite_lanuguages = {'jen': 'python' , 'sarah' : 'c' , 'edward' : 'rust' , 'phil' : 'python'}
print("The following languages have been mentioned:")
for language in favorite_lanuguages.values():
    print(language.title())
favorite_lanuguages = {"snip"}
print("The following languages have been mentioned:")
for language in set(favorite_languages.values()):
    print(language.title())
#Denfine the glossary dictionary
glossary = {'Variable': 'A named reference to a value.', 'list': 'A collection of items that can be of different types:', 'dictionary': 'A collection of key-value pairs.', 'function' : 'A block of organzied, reusable code.' 'A programming construct that repeats a group of statements.' , 'module': 'A file containing Python code.'}
#Loop through the dictionary and print each key-value pair
#Adding five more Python terms to the glossary
glossary['class']='A blueprint for creating objects.'
glossary['inheritance'] = 'The ability of a class to inherit properties and behavior from another class.'
glossary['method'] = 'A function defined within a class.'
glossary['attribute'] = 'A value associated with an object.'
glossary['exception'] = 'An error that occurs during the execution of a program.'
#Loop through the updated dictionary and print each key-value pair
print("\nUpdated glossary:")
#Create a dictionary of rivers and the countries they run through countries they run through
river = {'Nile': 'Egypt' , 'Amazon': 'Brazil' , 'Yangtze': 'China'}
#Loop through the dictionary and print sentence about each river
for river, country in river.items():
    print(f"The{river} runs through{country}.")
#Create a dictionary of rivers and the countries they run through
rivers = {'Nile': 'Egypt' , 'Amazon' : 'Brazil' , 'Yangtze': 'China'}
#Create a dictionary of rivers and the countries they run through
rivers = {'Nile': 'Amazon' 'Brazil' , 'Yangtze': 'China'}
#Create a set to store unique country names
unique_countries = set()
#Create a set to store unique country names
unique_countries = set()
#lterate over the value in the rivers dictionary to find unique country names
for country in rivers.values():
    unique_countries.add(country)
#Print the unique country names
print("Countries included in the dictionary of rivers.")
for country in unique_countries:
    print(country)
#Dictionary of favorite languages
favorite_language = {'jen': 'python' , 'sarah':  'c' , 'edward': 'ruby' , 'phil': 'python'}
#List of people who should take the favorite language poll
peopel_to_poll = ['jen' , 'sarah' , 'michael' , 'emma' , 'chris']
#Lterate over the list of the people check if they are already in the dictionary
#If not, prompt them to take the poll
for person in favorite_languages:
    print(f"Thank you,{person.title()}, for taking the favorite languages poll!")
#Dictionary of favorite languages
favorite_language = {'jen': 'python' , 'sarah': 'c' , 'edward': 'ruby' , 'phil': 'python'}
#Loop through the list of people and check if they have taken the poll
for person in peopel_to_poll:
    if person in favorite_languages:
      print(f"Thank you,{person.title()},for responding to the favorite languages poll!")
    else:
        print(f"{person.title()}, you are invited to take the favorite languages poll.")
alien_0 = {'color': 'green' , 'points' : 5}
alien_1 = {'color' : 'yellow' , 'points': 10}
alien_2 = {'color' : 'red' , 'points' : 15}
aliens = [alien_0 , alien_1 , alien_2]
for alien in aliens:
    print(alien)
{'color': 'green' , 'points' : 5}
{'color' : 'yellow' , 'points' : 10}
{'color' : 'red' , 'points' : 15}
#Make an empty list for storing aliens.
aliens = []
#Make 30 green aliens.
for alien_number in range(30):
    new_alien = {'color' : 'green' , 'points': 5 , 'speed': 'slow'}
    aliens.append(new_alien)
#Show the first 5 aliens.
for alien in aliens[:5]:
    print(alien)
print("...")
#Show how many aliens have been created.
print(f"Total number of aliens: {len(aliens)}")
{'color' : 'green' ,'points' : 5 , 'speed' : 'slow'}
{'color': 'green' , 'points' : 5 , 'speed' : 'slow'}
{'color': 'green' , 'points': 5 , 'speed' : 'slow'}
{'color': 'green' , 'points' : 5 , 'speed' : 'slow'}
{'color' : 'green' ,'points' : 5, 'speed' :  'slow'}
#Make an empty list for storing aliens>
aliens = []
#Make 30 green aliens.
for alien_number in range (30):
    new_alien = {'color' : 'green' , 'points': 5, 'speed' : 'slow'}
    aliens.append(new_alien)
for alien in aliens[:3]:
    if alien['color'] == 'green':
       alien['color'] =  'yellow'
       alien['points'] = 'medium'
       alien['points'] = 10
# Show the first 5 aliens.
for aliens in aliens[:5]:
    print(alien)
print("...")
{'color': 'yellow' , 'points' : 10, 'speed' : 'medium'}
{'color': 'yellow' , 'points' : 10, 'speed' : 'medium'}
{'color': 'yellow' , 'points':  10 , 'speed' : 'medium'}
{'color': 'yellow' , 'points' : 5 , 'speed' : 'medium'}
{'color' : 'green' , 'points' : 5 , 'speed' : 'slow'}
{'color' : 'green' , 'points' : 5 , 'speed' : 'slow'}
for alien in aliens[0:3]:
    if alien['color'] == 'green':
       alien['color'] = 'yellow'
       alien['speed'] = 'medium'
       alien['points'] = 10
    elif alien['color'] == 'yellow':
         alien['color'] = 'red'
         alien['speed'] = 'fast'
         alien['points'] = 15
#Store information about a pizza being ordered.
pizza = {'crust' : 'thick' , 'toppings' : ['mushrooms']}
#Summarize the order.
print(f"You ordered a {pizza['crust']}-crust pizza with the following toppings:")
for topping in pizza['toppings']:
    print(f"\t{topping}")
favorite_languages = {'jen':['python' , 'rust'] , 'sarah': ['c'] , 'edward' : ['rust' , 'go'] , 'phil' : ['python' , 'haskell']}
for name , language in favorite_languages.items():
    print(f"\n{name.title()}'s favorite languages are:")
    for language in language:
        print(f"\t{language.title()}")
users = {'aeinstein' : {'first': 'albert' , 'last': 'einstein' , 'location': 'princenton', 'mcurie': {'first': 'marie' , 'last' : 'curie' , 'location' : 'paris'} }}
for username , user_info in users.items():
    print(f"\nusername:{username}")
    full_name = f"{user_info['first']}{user_info['last']}"
    location = user_info['location']
    print(f"\tFull name:{full_name.title()}")
    print(f"\tLocation: {location.title()}")
#Denfine the initial dictionary for a person
person1 = {'first_name': 'John' , 'last_name': 'Doe' , 'age': 30, 'city': 'New York'}
#Denfine two more dictionaries for different people
person2 = {'first_name': 'Alice' , 'last_name': 'Smith' , 'age':25 , 'city': 'Los Angeles'}
person3 = {'first_name': 'Bob' , 'last_name': 'Johnson' , 'age': 35 , 'city': 'Chircago'}
#Create a list to store all the people dictionaries
people = [person1, person2 , person3]
#Loop through the list of people and print information about each person
for person in people:
  print("First Name:" , person['first_name'])
  print("last_name:" , person['last_name'])
  print("Age:" , person['age'])
  print("City:" , person['city'] )
  print()#Add a blank line for readabiltiy
  #Define dictionaries for different pets
  pet1 = {'animal': 'dog' , 'owner': 'Alice'}
  pet2 = {'animal': 'cat' , 'owner': 'Bob'}
  pet3 ={'animal': 'bird' , 'owner': 'Charlie'}
  #Store the pet dictionaries in a list.
  pets = [pet1 , pet2 , pet3]
  #Loop through the list of pets and print information about each pet
  for pet in pets:
      print("Pet")
      print("Animal:",pet['animal'])
      print("Ower:,pet['onwer']")
      print()#Add a blank line for readability
#Initialze the favorite_places dictionary with some sample data
      favorite_places = {'Alice':['Paris' , 'Tokyo'], 'Bob':['New York'], 'Charlie':['Sydney' , 'Rome' , 'Barcelona']}
#Loop through the favorite_places dictionary and print the favorite places for each person
for person, places in favorite_places.items():
    print(f"{person}'s favorite places.")
    for place in places:

      print()
#Modify the program to store multiple favorite numbers for each person
favorite_numbers = {'Alice':[7,11,22],'Bob':[3,8],'Charlie':[5,10,15]}
#Loop through the favorite_numbers dictionary and print each person's name along with their favorite numbers
for person , number in favorite_numbers.item():
    print(f"{person}'s favorite numbers:")
    for number in number:
     print("-" + str(number))
    print()#Add a blank line for readabitlity
#Define a dictionary of citites with information about each city
cities = {'New York': 'country' 'USA', 'population':8398748, 'fact': 'New York City is know as "The Big Apple".' 'Tokyo:' 'country' 'Japan', 'population':9270000, 'fact': 'Tokyo is the capital and largrest city of Japan' }
#Loop through the citites dictionary and print information about each city
for city, city_info in cities.items():
    print(f"City:{city}")
    print(f"Country:{city_info['country']}")
    print(f"Population:{city_info['population']}")
    print(f"Fact:{city_info['fact']}")
    print()#Add a blank line readabitity
    class ShoppingCart:
       def __init__(self):
        self.items ={}
       def add_item(self,item,price):
           if item in self.items:
              self.item[item]+=price
           else:
                self.item[item]+=price
       def remove_item(self,item):
           if item in self.items:
              del self.items[item]
           else:
               print("item not found in the cat.")
       def display_cart(self):
           print("Shopping Cart:")
           for item , price in self.items.item():
            print(f"{item}:${price}")
#Create a shopping cart
cart = ShoppingCart()
#Add items to the cart
cart.add_item("Apple",2.0)
cart.add_item("Banana",1.0)
cart.add_item("Orange",1.5)
#Display the current cart
cart.display_cart()
print("Shopping Cart:")
for item, price in Self.itmes.items():
    print(f"{item}:{price}")
#Create a shopping cart
cart = ShoppingCart()
#Add itmes to the cart
cart.add_item("Apple",2.0)
cart.add_item("Banana",1.0)
cart.add_item("Orange",1.5)
#Display the current cart
cart.display_cart()
class ShoppingCart:
    def __init__(self):
       self.items={}
def add_item(self,item,price):
    if item in self.items:
      self.items[item]+=price
    else:
        self.items[item]=price
def remove_item(self,item):
    if item in self.items:
       del self.items[item]
    else:
         print("item not found in the cart.")
def display_cart(self):
    print("Shopping Cart:")
    for item price in self.item.item():
print(f"{item}:{price}")
def calculate_total_price(self):
    total = sum(self.items.value())
print(f"Total Price:{total}")
#Create a shopping cart
cart = ShoppingCart()
#Add items to the cart
cart.add_item("Apple", 2.0)
cart.add_item("Banan",1.0)
cart.add_item("Orange", 1.5)
#Displaythe current cart
cart.display_cart()
#Display the total price
cart.calculate_total_price()
#Read the file and create a dictonary with names as keys and grade as value
grade_dict = {}
with open('grade.txt','r') as file:
     for line in file:
      name,grade = line.strip().split()
      grade_dict[name]=int(grade)
#print out the dictionary stored by name alphabetically
sorted_by_name =
dict(sorted(grade_dict.items(),key=lambda x: x[1],reverse=True))
print("\nSorted by grades(from highest to lowest:)")
for name, grade in sorted_by_name.items():
    print(f"{name}:{grade}")
#Create a file named graded.txt with name and grade lines
data = ["Alice 90"  , "Bob 85" , "Charlie 95" , "David 88" , "Eve 92"]
with open('grades.txt','w')as file:
     for line in data:
         file.write(line+'\n')
#Read the file and create a dictionary with names as key and grades as values
grades_dict = {}
with open('grades.txt' , 'r') as file:
     for line in file:
      name,grade=line.strip().spilt()
      grade_dict[name]=int(grade)
#Print out the created dictionary
print("Dictionary where the key is the name and the value is the grade:")
print(grade_dict)
# Out:
#   File "<ipython-input-1-59f3cdb49623>", line 332
#     for item price in self.item.item():
#              ^
# SyntaxError: invalid syntax
