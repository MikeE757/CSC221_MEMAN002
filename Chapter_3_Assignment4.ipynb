# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeE757/CSC221_MEMAN002/blob/main/Chapter_3_Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bicycles = ['trek','cannondale','redline','specialied']
print(bicycles)
bicycles = ['trek' , 'cannondale' , 'redline' , 'specialized']
print(bicycles[0])
bicycles = ['trek','cannondale','redline','specialized']
print(bicycles[0].title())
bicycles = ['trek','cannondale','redline','specialized']
print(bicycles[1])
print(bicycles[3])
bicycles = ['trek','cannondale','redline','specialized']
message = f"My first bicycles was a {bicycles[0].title()}."
print(message)
names = ["Alice" , "Bob" , "Charlie" , "David" , "Eve"]
#Print each person's name by accessing each element in the list
for i in range(len(names)):
 print(names[i])
#Store the names of your friends in a list called names
names = ["Alice" , "Bob" , "Charlie" , "David" , "Eve"]
#Print a personalized message to each person in the list
for name in names:
    print(f"Hello,{name}! I hope you are having a great day!")
#List of favorite modes of transportion
transportion_models = ["electric scooter","sport car" , "bicycle" , "private jet" , "yacht"]
#Print statement about transportation models
for transportation in transportion_models:
    print(f"I would like to ride a {transportation}.")
motorcycles = ['honda' , 'yamaha' , 'suzuki']
print(motorcycles)
motorcycles[0] = 'ducati'
print(motorcycles)
motorcycles = ['honda' , 'yamaha' , 'suzuki']
print(motorcycles)
motorcycles.append('ducati')
print(motorcycles)
motorcycles = []
motorcycles.append('honda')
motorcycles.append('yamaha')
motorcycles.append('suzuki')
print(motorcycles)
motorcycles = ['honda' , 'yamaha' , 'suzuki']
motorcycles.insert(0,'ducati')
motorcycles = ['honda' , 'yamaha' , 'suzuki']
print(motorcycles)
del motorcycles[0]
print(motorcycles)
motorcycles = ['honda' , 'yamaha' , 'suzuki']
print(motorcycles)
del motorcycles[1]
print(motorcycles)
motorcycles = ['honda' , 'yamaha' , 'suzuki']
print(motorcycles)
popped_motorcycle = motorcycles.pop()
print(motorcycles)
print(popped_motorcycle)
motorcycles = ['honda' , 'yamaha' , 'suzuki']
last_owned = motorcycles.pop()
print(f"The last motorcycle I owned was a {last_owned.title()}.")
motorcycles = ['honda' , 'yamaha' , 'suzuki']
first_owned = motorcycles.pop(0)
print(f"The first motorcycle I owned was a {first_owned.title()}.")
motorcycles = ['honda' , 'yamaha' , 'suzuki' , 'ducati']
print(motorcycles)
motorcycles.remove('ducati')
print(motorcycles)
motorcycles = ['honda', 'yamaha' , 'suzuki' , 'ducati']
print(motorcycles)
too_expensive = 'ducati'
motorcycles.remove(too_expensive)
print(motorcycles)
print(f"\nA{too_expensive.title()} is too expensive for me.")
#Inform guest about the bigger table
print("Great news! We  found a bigger table for our dinner party!")
#Add a new guest to the beginning of the list guest_list(0,"Ada Lovelace")
#Add a new guest to the middle of the list middle
#Invitation message
print(f"Dear Patrick, Amy, Peter, and David. You are cordially invited to a special dinner party. Your presence would make the evening truly memorable.\n Looking forward to seeing you!\n")
#Inital guest list
guest_list = ["Ada Lovelace" , "Maya Angelou" , "Albert Einstein" , "Nikloa Tesla" , "Marie Curie" , "Leonardo da Vinci" , "Galileo Galilei" , "Frida Kahlo"]
print("Unfortunately, the new dinner table won't arrive in time, and we can only invite two guest for dinner.")
# Removing guest using pop() and sending regrets
while len(guest_list) > 2:
  removed_guest = guest_list.pop()
  print(f"Sorry{removed_guest}, we can't invite you to dinner this time.")
  #Sending invitation to the remaining two guests
  for guest in guest_list:
     print(f"Dear Patrick, Amy , Peter, and David. You are still invited to the dininer party. Looking forward to seeing you!")
#Emptying the guest list using del
del guest_list[:]
# Printing the empty guest list
print("Final Guest List" , guest_list)
cars = ['bmw' , 'audi' , 'toyota' , 'subaru']
cars.sort()
print(cars)
cars = ['bmw' , 'audi' , 'toyota' , 'subaru']
cars.sort(reverse=True)
print(cars)
cars = ['bmw' , 'audi' , 'toyota' , 'subaru']
print("Here is the original list:")
print(cars)
print("\nHere is the sorted list:")
print(sorted(cars))
print("\nHere is the original list again:")
print(cars)
cars = ['bmw' , 'audi' , 'toyota' , 'subaru']
len(cars)
#List of five places to vist
places_to_vist = ["Tokyo , Japan" , "Banff National Park, Canada" , "Santorini, Greece" , "Machu Picchu, Peru" , "Serengeti National Park , Tanzania"]
print(places_to_vist)
#Original list of places to vist
place_to_vist = ['Great Barrierr Reef , Australia' , 'Machu Picchu , Peru ' , 'Santorini , Greece' , 'Yellowstone National Park , USA' , 'Kyoto, Japan']
#Print the orginal list
print("Original list of places to vist:")
print(places_to_vist)
#Print the sorted list in alphabetical order
print("\nSorted list in alphabetical order")
print(sorted(places_to_vist))
#List of five places to vist
places_to_vist = ['Paris,France' , 'Bail,Indonesia' , 'New York City,USA','Cape Town, South Africa', 'Tokyo, Japan']
#Print the list to show the orginal order
print("Orginal order of places to vist:")
print(places_to_vist)
#List of five places to vist
places_to_vist = ['Paris, France','Bali, Indonesia', 'New York City,USA','Capem Town South Africa','Tokyo,Japan']\
#Printing the list in reverse-alphabetical order using sorted()
print("List of places in reverse-alphabetical order:")
print(sorted(places_to_vist,reverse=True))
#List of five places to vist
places_to_vist = ['Paris,France','Bail,Indonesia','New York City,USA','Cape Town,South Africa','Tokyo,Japan']
#Print the orginal list
print("Orginal order of places to vist:")
print(places_to_vist)
#Reverse the order of the list
places_to_vist.reverse()
#Print the list to show the reversed order
print("\nReversed order of places to vist:")
print(places_to_vist)
#List of five places to vist
places_to_vist = ['Paris,France','Bail, Indonesia','New York City,USA','Cape Town,South Africa','Tokyo,Japan']
#Print the orginal list
print("Orginial order of places to vist:")
print(places_to_vist)
#Sort the list in reverse-alphabetical order
places_to_vist.sort(reverse=True)
#Print the list to show the reverse-alphabetical order
print("\nReversed alphabetical order of places to vist:")
print(places_to_vist)
motorcycles = ['honda' , 'yamaha' , 'suzuki']
print(motorcycles[-1])
