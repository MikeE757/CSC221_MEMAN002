# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeE757/CSC221_MEMAN002/blob/main/Chapter6_Assignment7_ipynb(New_new).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Alien_0 = {'color': 'Green','Points':5}
print(Alien_0['color'])
print(Alien_0['Points'])

Alien_0 = {'color': 'Green', 'points': 5}
Alien_0 = {'color': 'Green'}
Alien_0 = {'color':'Green'}
print(Alien_0['color'])

Alien_0 = {'color': 'Green' , 'points':5}
new_points = Alien_0['points']
print(f"You just earned {new_points} points!")

Alien_0 = {'color': 'Green', 'points':5}
print(Alien_0)
Alien_0['x_position']=0
Alien_0['y_position']=25
print(Alien_0)

{'color': 'Green', 'points':5}
{'color': 'Green', 'points':5 ,'x_position': 0, 'y_position': 25}

Alien_0 = {}
Alien_0['color'] = 'Green'
Alien_0['Points'] = 5
print(Alien_0)

Alien_0 = {'color': 'Green'}
print(f"The Alien is {Alien_0['color']}.")
Alien_0['color'] = 'Yellow'
print(f"The Alien is now {Alien_0['color']}.")

Alien_0['speed'] = 'fast'
Alien_0 = {'color': 'Green', 'points': 5}
print(Alien_0)

Alien_0 = {'color': 'Green', 'Points':5}
print(Alien_0)

favorite_languages ={'Jen': 'Python', 'Sarah': 'c', 'Edward': 'rust','Phil': 'Python'}

Alien_0 = {'color': 'Green' , 'Speed': 'slow'}
point_value = Alien_0.get('points', 'No point value assigned.')
print(point_value)

favorite_numbers= {'John':42,'Emma': 7 , 'Alex': 15 , 'Sarah': 3 , 'Mike': 12}
for name, number in favorite_numbers.items():
    print(f"{name}'s favorite number is {number}.")

favorite_numbers = {'John': 42, 'Emma': 7,'Alex':15 , 'Sarah': 3 , 'Mike':12}
for name, number in favorite_numbers.items():
    print(f"{name}'s favorite number is {number}.")

friends = ['Phil','Sarah']
for name in favorite_languages.keys():
    print(f"Hi{name.title()}.")
if name in friends:
   language = favorite_languages[name].title()
   print(f"\t{name.title()}, I see you love {language}!")

Alien_0 = {'color': 'Green' ,'points': 5}
Alien_1 = {'color': 'Yellow','Points': 10}
Alien_2 = {'color': 'Red','points': 15}
Aliens = [Alien_0, Alien_1,Alien_2]
for Alien in Aliens:
    print(Alien)

#Make an empty list for storing Aliens.
Aliens = []
# Make 30 Green Aliens.
for Aliens_number in range(30):
    new_Alien = {'color': 'Green' , 'points': 5 , 'speed': 'slow'}
    Aliens.append(new_Alien)
# Show the first 5 Aliens.
for Alien in Aliens[:5]:
    print(Alien)
print("...")
#Show how many Aliens have been created
print(f"Total number of Aliens:{len(Aliens)}")

{'color': 'Green','points':5, 'speed': 'slow'}
{'color': 'Green', 'points':5, 'speed': 'slow'}
{'color': 'Green', 'points': 5, 'speed': 'slow'}
{'color': 'Green', 'points': 5, 'speed': 'slow'}
{'color':  'Green', 'points': 5, 'speed': 'slow'}

#Make an empty list for storing Aliens.
Aliens = []

for Aliens_number in range (30):
       Alien = {'color': 'Green' , 'points': 5 , 'speed': 'slow'}
       Alien.append:(new_Alien)
       dict: Alien in Alien[:3]
       Alien['color'] == 'Green'
       Alien['color'] =  'Yellow'
       Alien['speed'] =  'medium'
       Alien['points']= 10

# Show the first 5 Aliens.
for Alien in Alien[:5]:
    print(Alien)
print("...")

{'color': 'Yellow', 'Points': 10, 'speed': 'medium'}
{'color': 'Yellow', 'points': 10, 'speed': 'medium'}
{'color': 'Yellow', 'points': 10, 'speed': 'medium'}
{'color': 'Yellow',  'points': 5, 'speed':'slow'}
{'color':  'Yellow',  'points':5, 'speed': 'slow'}

for Alien in Alien[:3]:
    if Alien['color'] == 'Green':
       Alien['color'] = 'Yellow'
       Alien['speed'] = 'medium'
       Alien['points'] = 10
    elif Alien['color'] == 'Yellow':
         Alien['color'] = 'Red'
         Alien['speed'] = 'fast'
         Alien['points'] = 15

print("First Name:",['John'])
print("Last Name:",['Doe'])
print("Age:",['30'])
print("City:",['New York City'])

Glossary = {'Variable': 'A named storage location in computer memory that can hold a vaule.', 'Function': 'A named block of code that performs a specific task and can be reused.', 'loop': 'A programming construct that repeats a set of instruction until a specific condition is met', 'Conditional statement': 'A classification of vaules that determines the operations that can be performed on them.'}
for word,meaning in Glossary.items():
    print(f"word.capitalize():{meaning}")

for Alien in Alien [0:3]:
  if Alien['color'] == 'Green':
      Alien['color'] = 'Yellow'
      Alien['speed'] = 'medium'
      Alien['Points'] = 10
  elif  Alien['color'] == 'Yellow':
      Alien['color'] = 'Red'
      Alien['speed'] = 'Fast'
      Alien['points'] = 15

pizza = {'Crust':'Thick','toppings':['Mushroom','Extra Cheese']}
# Summer the order.
print(f"You ordered a {pizza['Crust']}- crust pizza with the following toppings:")
for topping in pizza['toppings']:
    print(f"\t{topping}")


favorite_languages = {'Jen':['python','Rust'],'Sarah': ['C'],'Edward': ['Rust', 'Go'], 'Phil': ['Python', 'Haskell']}
for name, language in favorite_languages.items():
  print(f"\n{name.title()}'s favorite language are:")
  for language in language:
    print(f"\t{language.title()}")

users = {'Aeinstein': {'first': 'Albert', 'last':'Einstein', 'location':  'Princeton'},'Mucurie': {'first': 'Marie' , 'last': 'Curie' , 'location': 'Paris'}}
for username, user_info in users.items():
    print(f"\nUsername:{username}")
    full_name = f"{user_info['first']} {user_info['last']}"
    location = user_info['location']
    print(f"\tlocation:{location.title()}")

peopele = []
person1 = {'first_name': 'John', 'last_name': 'Doe' , 'age': 30, 'city': 'New York City'}
person2 = {'first_name': 'Jane' , 'last_name': 'Smith' ,'age': 25, 'city': 'London'}
person3 = {'first_name': 'Chris', 'last_name':  'Johnson','age': 35, 'city': 'Sydney'}
peopele.extend([person1, person2, person3])
for person in peopele:
  print("First Name:", person['first_name'])
  print("Last Name:" , person['last_name'])
  print("Age:", person['age'])
  print("City:", person['city'])
  print()

pets = []
pet1 = {'Animals': 'Dog' , 'Owner': 'John'}
pet2 = {'Animals': 'Cat' , 'Owner': 'Jane'}
pet3 = {'Animals': 'Bird', 'Owner':'Patrick'}
print()

favorite_places = {'John:'['Pais , Tokyo'] , 'Jane:'['New York'], 'Patrick:'['London']}
for person, place in favorite_places.items():
    print("person + favorite palces are")
    for place in place:
        print("- + place")
    print()

favorite_numbers = {'John':[7,14,21],'Jane':[3,9,12], 'Michael':[5,10,15,20]}
for person , numbers in favorite_numbers.items():
    print("person + favorite numbers are:")
    for number in numbers:
        print("-" + str(number))
    print()

cities = {'Tokyo': {'country': 'Japan' , 'population': 13929286 , 'fact': 'Tokyo is the most population city in Japan'}, 'Paris':{'country': 'France' , 'population': 2140526 , 'fact': 'Paris is known as the "City of Light".'}}, 'New York City:', {{'Country': 'United States' , 'population': 8537673 , 'fact': 'New York City is home to the Statue of Liberty.'}}



print("\nUpdated Glossary:")
for term, definiton in Glossary.items():
  print(f"{term.title()}:{definiton}")

rivers = {'Nile': 'Egypt' , 'Amazon': 'Brazil' , 'Yangtze': 'China' }

for river, country in rivers.items():
  print(f"The {river.title} runs through {country}.")

rivers = {'Nile': 'Egypt', 'Amazon': 'Brazil' , 'Yangtze': 'China'}
for river in rivers:
  print(river)

favorite_languages = {'Alice': 'Python' , 'Patrick': 'Java' , 'Timmy': 'C' , 'David': 'C+' , 'Sarah': 'C++'}
people_to_poll = ['Alice' , 'Patrick' , 'Timmy' , 'David' , 'Sarah' , 'Jeff' ,'Henry' , 'Mary' ]
for person in people_to_poll:
    if person in favorite_languages:
      print(f"Thanks,{person}! You've already taken the poll.")
    else:
      print(f"Hey,{person}! You should take the favorite languages poll.")


Alien_0 = {'color': 'Green', 'points': 5 }
Alien_1 = {'color' :'Yellow', 'points' : 10}
Alien_2 = {'color' : 'Red' ,  'points' : 15}

Aliens = [Alien_0 , Alien_1 , Alien_2]
for Alien in Aliens:
  print(Alien)


rivers = {'Nile' : 'Egypt' , 'Amazon': 'Brazil' , 'Yangtze': 'China'}
for river in river.values():
    print(river)
